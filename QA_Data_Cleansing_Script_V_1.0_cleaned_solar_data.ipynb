# %% [markdown]
# ## Errors addressed in Joshua's code
#
# 1. Translate data to English
#
#
# 2. Remove multiple commas
#
#
# 3. Correct truncated Questions at the end of a sentence
#
#
# 4. Correct invalid URL
#
#
# 5. Add space before open bracket
#
#
# 6. Correct truncated questions at the begining of a sentence or word
#
#
# 7. Capitalise first word in a sentence
#
#
# 8. Add Fullstop at the end of a sentence
#
#
# 9. Capitalise acronyms
#
#
# 10. Format number with commas
#
#
# 11. Remove whitespace

# %% [markdown]
# ## Note, Please install java on your system

# %% [markdown]
# # Description
# This script constitutes a data cleaning pipeline designed for processing the initial Q&A dataset. It accepts the unrefined Q&A dataset as input and yields a refined version suitable for further applications.
#
# Following is a list of addressed errors (Please keep adding any additional errors addressed in future) -
# 1. Translation to English
# 2. Replace multiple commas
# 3. Extra character at the start of a Q/A
# 4. Numbers not formatted ("....1236337km2..." to "1,236,337km2...")
# 5. Invalid URL
#
#
#
# Solved using Language Tool function
# 6. Answer not started in UpperCase
#
# 7. Missing apostrophe
# 8. Compound words without hyphen
# 9. Proper Noun
# 10. Incorrect capitalisation
# 11. Missing space (Done?)
#
# Overall, the code aims to clean, correct, and preprocess data in the Q&A DataFrame, focusing on specific errors.

# %% [markdown]
# # <b>Instructions for running the script </b>
#
# 1. Install all neccessary python packages.
#
#
# 2. Make sure the source dataset is a .CSV file with a single table format that includes a 'Question' and an 'Answer' column.
#
#
# 3. Change the directory/path to your directory in 'def main()' method for the variable 'CSV_files'(source file path), 'filtered_data_file'(unclean/eliminated records) and 'cleaned_df_dir' (final clean dataset)
#
#
# <b>NOTE: Please change the version number in the title, incase of any additions/changes to script inorder to identify the latest version of the script</b>.

# %% [markdown]
# ### Install required python packages

# %%
#!pip install language_tool_python spacy textblob

# %%
#!python -m spacy download en_core_web_sm

# %%
#!pip install googletrans==4.0.0-rc1

# %%
#!pip install pyenchant

# %%
#!pip uninstall language-tool-python
#!pip install language-tool-python

# %% [markdown]
# ## Install necessary libraries

# %%
import pandas as pd
import os
import csv
import re
import language_tool_python
import time
import cProfile
from textblob import TextBlob
import spacy
from urllib.parse import urlparse, urlunparse
import locale
import nltk
from nltk.corpus import stopwords
import re
from googletrans import Translator
from tqdm import tqdm

# %% [markdown]
# ## Activate the java

# %%
# Set the JAVA_HOME environment variable to the path of your Java installation
os.environ["JAVA_HOME"] = "C:/Path/To/Java"

# import the language_tool_python module
tool = language_tool_python.LanguageTool('en-GB')
# Out:
# Downloading LanguageTool 5.7: 100%|█████████████████████████████████████████████████| 225M/225M [03:36<00:00, 1.04MB/s]
# Unzipping C:\Users\rosem\AppData\Local\Temp\tmpnpr7_967.zip to C:\Users\rosem\.cache\language_tool_python.
# Downloaded https://www.languagetool.org/download/LanguageTool-5.7.zip to C:\Users\rosem\.cache\language_tool_python.

# %%
# Read the data
df = pd.read_csv('solar_panel_modified_data.csv')
df.head(2)
# Out:
#    id                                           Question  \
# 0   1            What is the main purpose of this paper?
# 1   2  What are the key words associated with this pa...
#
#                                               Answer
# 0  The main purpose of this paper is to present a...
# 1  The key words associated with this paper are R...

# %%
# Check the number of rows and column
df.shape
# Out:
# (3368, 3)

# %% [markdown]
# ## Translate data to English

# %%
def translate_to_english(qa_df):
    translator = Translator()
    count = 0
    qa_list = []
    translated_records = []

    # Select Q&A from each record
    for i in range(qa_df.shape[0]):
        qa_list.append([qa_df['Question'][i], qa_df['Answer'][i]])
    
    print("Translating dataset:")
    for i, sent in tqdm(enumerate(qa_list), total=len(qa_list)):
        detected_language_Q = 'en'
        detected_language_A = 'en'

        try:
            # Detect the language of the text
            detected_language_Q = translator.detect(sent[0]).lang
            detected_language_A = translator.detect(sent[1]).lang

            if detected_language_Q != 'en':
                count += 1
                # Translate the text to English
                translation_Q = translator.translate(sent[0], src=detected_language_Q, dest='en')
                qa_list[i][0] = translation_Q.text

            if detected_language_A != 'en':
                count += 1
                # Translate the text to English
                translation_A = translator.translate(sent[1], src=detected_language_A, dest='en')
                qa_list[i][1] = translation_A.text

        except Exception as e:
            # Future scope to find another package that can cover unidentified languages
            pass

    # Unzip the list of tuples into separate lists for each column
    Question, Answer = zip(*qa_list)

    # Replace the existing columns with the new translated values
    qa_df['Question'] = Question
    qa_df['Answer'] = Answer

    return qa_df, count, translated_records

# Call the function
translated_df, translation_count, _ = translate_to_english(df)

# Output
print("\nTranslated DataFrame:")
print(translated_df)
print("\nNumber of Records Translated:", translation_count)
# Out:
# Translating dataset:
# 100%|██████████████████████████████████████████████████████████████████████████████| 3368/3368 [35:41<00:00,  1.57it/s]
# Translated DataFrame:
#         id                                           Question  \
# 0        1            What is the main purpose of this paper?
# 1        2  What are the key words associated with this pa...
# 2        3                                     What is MIVES?
# 3        4             What is the advantage of PV/T over PV?
# 4        7  What are the measures necessary to reduce ener...
# ...    ...                                                ...
# 3363  4286  What algorithm was used in Maghraoui et al. (2...
# 3364  4287  What is the DOI for the journal article "RMSE ...
# 3365  4288  What is the title of the paper presented at th...
# 3366  4289  What model did Sauer et al. apply to forecasti...
# 3367  4290  How many machine-learning methods were studied...
#
#                                                  Answer
# 0     The main purpose of this paper is to present a...
# 1     The key words associated with this paper are R...
# 2     MIVES stands for the integrated value model fo...
# 3     PV/T is a better solution when stakeholders ar...
# 4     Reducing energy needs with measures such as le...
# ...                                                 ...
# 3363  Maghraoui et al. (2022) used a comparative stu...
# 3364  The DOI for the journal article "RMSE - root m...
# 3365  The title of the paper presented at the 2021 I...
# 3366  Sauer et al. applied an Extreme Gradient Boost...
# 3367  Sharifzadeh et al. studied three machine-learn...
#
# [3368 rows x 3 columns]
#
# Number of Records Translated: 84

# %% [markdown]
# ## Save the translated data

# %%
# Save the data translated
df.to_csv('solar_trans_data.csv', index=False)

# %% [markdown]
# ## Define the errors and solution

# %%
def count_multiple_commas(text):
    """
    This function counts the occurrences of consecutive commas in a given text.

    Args:
        text (str): The input text to be analyzed.

    Returns:
        int: The count of consecutive commas.

        If the input is not a string, it returns the input as is.
    """
    if isinstance(text, str): # Checking if the input is a string
        pattern = re.compile(r',{2,}') # Defining a regular expression pattern to find consecutive commas
        return len(re.findall(pattern, text)) # Counting the occurrences of the pattern and returning the count
    else:
        return text  # If the input is not a string, return it as is
    
    
def replace_multiple_commas(text):
    """
    This function replaces consecutive commas with a single comma followed by a space in a given text.

    Args:
        text (str): The input text to be processed.

    Returns:
        str: The modified text with consecutive commas replaced.

        If the input is not a string, it returns the input as is.
    """
    if isinstance(text, str):  # Checking if the input is a string
        pattern = re.compile(r',{2,}')  # Defining a regular expression pattern to find consecutive commas
        corrected_text = re.sub(pattern, ', ', text)  # Replacing consecutive commas with ', ' in the text

        if corrected_text != text:  # Checking if any replacement was made
            print(f"\nOriginal text: {text}")
            print(f"Corrected text: {corrected_text}")

        return corrected_text  # Returning the modified text
    else:
        return text  # If the input is not a string, return it as is



'''
def comma_cluster_removal_df(df):
    total_comma_count = 0

    for column in df.columns:
        df[column] = df[column].apply(replace_multiple_commas)
        total_comma_count += df[column].apply(count_multiple_commas).sum()

    print(f"Total comma count: {total_comma_count}")
    return df, total_comma_count
'''


def comma_cluster_removal_df(df):
    """
    This function processes a DataFrame to remove comma clusters in its columns.

    Args:
        df (pd.DataFrame): The DataFrame to be processed.

    Returns:
        pd.DataFrame: The modified DataFrame with comma clusters removed.
        int: The total count of commas removed.

    Note:
        This function assumes that 'replace_multiple_commas' and 'count_multiple_commas' functions are defined elsewhere.
    """
    total_comma_count = 0  # Initializing a variable to keep track of the total comma count

    # Loop through each column in the DataFrame
    for column in df.columns:
        df[column] = df[column].apply(replace_multiple_commas)  # Apply 'replace_multiple_commas' to the column
        total_comma_count += df[column].apply(count_multiple_commas).sum()  # Count commas and add to total

    print(f"Total comma count: {total_comma_count}")  # Print the total comma count
    return df, total_comma_count  # Return the modified DataFrame and total comma count



def is_truncated(sentence):
    """
    This function checks if a sentence is truncated, meaning it lacks proper sentence-ending punctuation.

    Args:
        sentence (str): The input sentence to be analyzed.

    Returns:
        bool: True if the sentence is truncated, False otherwise.
    """
    # Ensure the sentence is converted to a string
    sentence = str(sentence)
    # Define a list of sentence-ending punctuation marks
    sentence_endings = ['.', '!', '?', '."', '!"', '?"', '.”', '!”', '?”']

    # Check if the sentence is empty or very short
    if len(sentence) < 2:
        return False  # Not truncated

    # Check if the last character of the sentence is a sentence-ending punctuation mark
    if sentence[-1] in sentence_endings:
        return False  # Not truncated
    else:
        print ("\n" + sentence+"\n")
        return True   # Truncated
    
    
'''
def is_undesirable_question_to_count(question):
    if isinstance(question, str):
        count_phrases = [

            "what is the title",
            "what is the research topic",
            "what data is used in the study",
            "what data sets are collected in this study",
            "how did the study",
            "what does the arrow in figure 6 represent",
            "what was the publication date of the study",
            "what is the title of the paper",
            "what is the purpose of this study",
            "what was the goal of the study",
            "what data was utilized in the study",
            "what is the source of funding for this study",
            "what was the aim of this study",
            "what are the objectives of the study",
            "what was the main focus of the study",
            "what were the main conclusions of the study",
            "what methods were used in the study",
            "what ratio was used for the analysis",
            "what models are shown in fig 4",
            "what is the conclusion of this study",
            "what do the innovations of this study enable",
            "what is the article about",
            "what is the doi number for the article",
            "where can the tool be accessed",
            "what data has been used",
            "what were the results of the study",
            "what are the key findings of this study",
            "what data sources were used in this study",
            "what are the limitations of this study",
            "where was the research conducted",
            "what are the key words for this article",
            "what is the main objective of this study",
            "what evidence supports the research",
            # Add more phrases here
        ]
        return any(phrase in question.lower() for phrase in count_phrases)
    return False
'''


def is_undesirable_question_to_count(question):
    """
    This function checks if a given question is considered an 'undesirable' question for counting purposes.

    Args:
        question (str): The input question to be analyzed.

    Returns:
        bool: True if the question is undesirable for counting, False otherwise.
    """
    if isinstance(question, str):  # Checking if the input is a string
        count_phrases = [
            # List of phrases that indicate undesirable questions
            # If any of these phrases are found in the question (case insensitive), the function returns True
            "what is the title",
            "what is the research topic",
            "what data is used in the study",
            "what data sets are collected in this study",
            "how did the study",
            "what does the arrow in figure 6 represent",
            "what was the publication date of the study",
            "what is the title of the paper",
            "what is the purpose of this study",
            "what was the goal of the study",
            "what data was utilized in the study",
            "what is the source of funding for this study",
            "what was the aim of this study",
            "what are the objectives of the study",
            "what was the main focus of the study",
            "what were the main conclusions of the study",
            "what methods were used in the study",
            "what ratio was used for the analysis",
            "what models are shown in fig 4",
            "what is the conclusion of this study",
            "what do the innovations of this study enable",
            "what is the article about",
            "what is the doi number for the article",
            "where can the tool be accessed",
            "what data has been used",
            "what were the results of the study",
            "what are the key findings of this study",
            "what data sources were used in this study",
            "what are the limitations of this study",
            "where was the research conducted",
            "what are the key words for this article",
            "what is the main objective of this study",
            "what evidence supports the research",

            # Add more phrases here as needed
        ]
        return any(phrase in question.lower() for phrase in count_phrases)  # Checking if any phrase is present in the question
    return False  # If the input is not a string, return False



# Assuming you have defined your functions is_undesirable_question_to_count and is_truncated properly
def count_truncated_questions_and_answers_in_df(df, filtered_data_file):
    """
    This function processes a DataFrame to count truncated questions and answers, and filter out undesirable data.

    Args:
        df (pd.DataFrame): The DataFrame to be processed.
        filtered_data_file (str): The file path to save the filtered data.

    Returns:
        int: The count of undesirable questions.
        int: The count of truncated questions.
        int: The count of truncated answers.
        pd.DataFrame: The DataFrame containing remaining data without truncated questions and answers.
    """
    #df = pd.read_csv(file_path)
    df.info()
    columns_with_spaces = df.columns.tolist()
    print(columns_with_spaces)
    questions = df['Question']
    answers = df['Answer']

    questions_count = df['Question'].apply(is_undesirable_question_to_count).sum()

    # Count truncated questions
    truncated_questions_count = df['Question'].apply(is_truncated).sum()

    # Count truncated answers
    truncated_answers_count = df['Answer'].apply(is_truncated).sum()

    # Filter out truncated rows
    truncated_questions = []
    truncated_answers = []

    # Filter out truncated rows
    not_truncated_indices = []
    for i in range(len(df)):
        if not (is_truncated(questions[i]) or is_truncated(answers[i])):
            not_truncated_indices.append(i)
        else:
            if is_truncated(questions[i]):
                truncated_questions.append(questions[i])
                print(f"Truncated Question {i}: {questions[i]}")
            if is_truncated(answers[i]):
                truncated_answers.append(answers[i])
                print(f"Corresponding Question {i}: {questions[i]}")
                print(f"Truncated Answer  {i}: {answers[i]} \n")
    df = df.iloc[not_truncated_indices]

    # Filter out questions and their corresponding answers
    filtered_indices = [i for i, question in enumerate(df['Question']) if is_undesirable_question_to_count(question)]
    filtered_data = pd.DataFrame({
        'Question': df['Question'].iloc[filtered_indices],
        'Answer': df['Answer'].iloc[filtered_indices]
    })

    # Print the number of rows in the filtered data
    print("Number of rows in filtered data:", len(filtered_data))

    # Create a new DataFrame for remaining data without truncated QnA
    remaining_indices = [i for i in range(len(df)) if i not in filtered_indices]
    remaining_data = df.iloc[remaining_indices]

    # Print the number of rows in the remaining data
    print("Number of rows in remaining data:", len(remaining_data))

    # Save the filtered data
    filtered_data.to_csv(filtered_data_file, index=False, encoding='utf-8')

    # Save the remaining data
    #remaining_data.to_csv(remaining_data_file, index=False, encoding='utf-8')

    return questions_count, truncated_questions_count, truncated_answers_count, remaining_data



def save_filtered_data(file_path, filtered_data):
    """
    This function saves filtered data to a CSV file.

    Args:
        file_path (str): The file path where the filtered data will be saved.
        filtered_data (list): List of dictionaries containing 'Question' and 'Answer' pairs.

    Returns:
        None
    """
    with open(file_path, 'w', newline='', encoding='utf-8') as csvfile:
        fieldnames = ['Question', 'Answer']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

        writer.writeheader()  # Write the header row
        writer.writerows(filtered_data)  # Write the filtered data
        

def count_errors(text):
    """
    This function counts the number of errors in a given text.

    Args:
        text (str): The input text to be checked for errors.

    Returns:
        int: The number of errors found in the text.
    """
    tool = language_tool_python.LanguageTool('en-GB')  # Initialize a language checking tool
    matches = tool.check(text)  # Check the text for errors
    return len(matches)  # Return the number of errors found



def LanguageTool_df(df):
    """
    This function applies language correction using LanguageTool to the cells of a DataFrame.

    Args:
        df (pd.DataFrame): The DataFrame to be processed.

    Returns:
        pd.DataFrame: The DataFrame with language corrections applied.
    """
    tool = language_tool_python.LanguageTool('en-GB')  # Initialize a language checking tool

    corrected_content = []  # List to store corrected content

    #original_error_count = 0
    #corrected_error_count = 0

    for i in tqdm(range(len(df))):
        corrected_row = []  # List to store corrected row content
        for cell in df.iloc[i]:  # Iterate through each cell in the row
            if isinstance(cell, str):  # Check if the cell contains a string
                corrected_cell = tool.correct(cell)  # Apply language correction
                corrected_cell = corrected_cell.replace(' Answer', 'Answer')  # Additional specific correction
            else:
                corrected_cell = cell  # If not a string, keep the cell as is
            corrected_row.append(corrected_cell)  # Add the corrected cell to the row
        corrected_content.append(corrected_row)  # Add the corrected row to the content list

    LanguageTool_corrected_df = pd.DataFrame(corrected_content, columns=df.columns)  # Create a new DataFrame with corrections

    return LanguageTool_corrected_df  # Return the DataFrame with language corrections



# Assuming you have a function count_errors defined elsewhere in your code
# Example usage:
# corrected_df, original_errors, corrected_errors = LanguageTool_df(your_dataframe)

def validate_and_correct_url_in_dataframe(df):
    """
    This function validates and corrects URLs in a DataFrame.

    Args:
        df (pd.DataFrame): The DataFrame to be processed.

    Returns:
        pd.DataFrame: The DataFrame with validated and corrected URLs.
    """
    def validate_and_correct_url(url):
        """
        This nested function validates and corrects a single URL.

        Args:
            url (str): The input URL to be validated and corrected.

        Returns:
            str: The corrected URL.
        """
        if isinstance(url, str):
            try:
                parsed_url = urlparse(url)
                if not parsed_url.scheme:
                    # If the URL doesn't have a scheme (e.g., http://), add "http://"
                    corrected_url = 'http://' + url
                    parsed_url = urlparse(corrected_url)

                if not parsed_url.netloc:
                    # If the URL doesn't have a valid network location, return it as is
                    return url

                # Replace "www" with "www." if it doesn't have a dot after it
                corrected_netloc = re.sub(r'www(?!\.)', 'www.', parsed_url.netloc)

                # Replace "com" with ".com" if it doesn't have a dot before it, and is not followed by a forward slash
                corrected_netloc = re.sub(r'(?<!\.)com(?!/)', '.com', corrected_netloc)

                 # Replace "com" with ".org" if it doesn't have a dot before it, and is not followed by a forward slash
                corrected_netloc = re.sub(r'(?<!\.)org(?!/)', '.org', corrected_netloc)


               # Remove dots from ".com" in the middle of the string
                corrected_netloc = re.sub(r'(?<=\w)\.com(?=\w)', 'com', corrected_netloc)

                # Remove dots from ".org" in the middle of the string
                corrected_netloc = re.sub(r'(?<=\w)\.org(?=\w)', 'org', corrected_netloc)


                 # Replace ".com" at the start of a word with "com"
                corrected_netloc = re.sub(r'\.com(?=\w)', 'com', corrected_netloc)

                 # Replace ".com" at the start of a word with "org"
                corrected_netloc = re.sub(r'\.org(?=\w)', 'org', corrected_netloc)


                # Reassemble the URL with the corrected netloc
                parsed_url = parsed_url._replace(netloc=corrected_netloc)
                corrected_url = urlunparse(parsed_url)

                return corrected_url

            except ValueError:
                # Invalid URL, return it as is
                return url
        else:
            # If the input is not a string (e.g., it's a float or other non-string type),
            # return it as is
            return url

    if 'Full_Text_URL' in df.columns:
        df['Full_Text_URL'] = df['Full_Text_URL'].apply(validate_and_correct_url)

    return df



def add_space_before_opening_bracket(df):
    """
    This function adds a space before an opening bracket in string cells of a DataFrame.

    Args:
        df (pd.DataFrame): The DataFrame to be processed.

    Returns:
        pd.DataFrame: The DataFrame with spaces added before opening brackets.
    """
    #df = pd.read_csv(input_file_path)

    for column in df.columns:
        df[column] = df[column].apply(lambda cell: re.sub(r'([A-Za-z])\(', r'\1 (', cell) if isinstance(cell, str) else cell)

    #df.to_csv(ammended_space_file, index=False)

    return df   # Return the output file path after processing



# Function to correct the truncated starting word of the answers
def correct_truncated_start_word(text: str) -> str:
    if isinstance(text, str):
        # Load the spaCy English model
        nlp = spacy.load("en_core_web_sm")
        doc = nlp(text)

        # Checking if the start token is capitalized or not
        if doc[0].is_title == False:
            first_token = doc[0].text
            if first_token[0].isdigit() and not first_token[-1].isalnum():
                # Correct the word without modifying the '%' symbol
                corrected_word = ''.join([str(TextBlob(part).correct()) if not part.isalnum() else part for part in first_token.split('%')])
                corrected_text = corrected_word + " " + " ".join([token.text for token in doc[1:]])
                return corrected_text.capitalize()

        return text
    else:
        return text

def add_full_stops(df):
# function to add full stops to the end of each “Answer” column.
    df['Answer']=df['Answer'].apply(lambda answer: answer.strip()+  '.' if isinstance(answer,str) else answer)
    return df



# Download NLTK data for part-of-speech tagging
nltk.download('punkt')
nltk.download('stopwords')

# POS tagger
tagger = nltk.pos_tag

# Function to check if a word is a noun or other parts of speech
def is_noun_or_other(word):
    tagged = tagger([word])
    pos_tags = ['NN', 'NNS', 'NNP', 'NNPS', 'VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ', 'JJ', 'JJR', 'JJS', 'WP', 'IN']
    return tagged[0][1] in pos_tags

# Function to identify acronyms that are not stopwords and are nouns or other parts of speech
def identify_and_capitalize_acronyms(df, acronyms_df, persons_df):
    # Preprocess acronyms: remove whitespace and lowercase
    acronyms_df['Acronyms'] = acronyms_df['Acronyms'].str.replace(r'\s+', '').str.lower()
    acronyms = set(acronyms_df['Acronyms'])

    # Get the set of English stopwords
    english_stopwords = set(stopwords.words('english'))

    # Preprocess DataFrame
    df['Question'] = df['Question'].str.lower()
    df['Answer'] = df['Answer'].str.lower()

    # Load names of persons into a set
    persons_set = set(persons_df['name'].str.lower())

    for index, row in df.iterrows():
        q_words = re.findall(r'\b\w+\b', row['Question'])
        a_words = re.findall(r'\b\w+\b', row['Answer'])

        q_matches = [word for word in q_words if word in acronyms and word not in english_stopwords and is_noun_or_other(word) and word not in persons_set]
        a_matches = [word for word in a_words if word in acronyms and word not in english_stopwords and is_noun_or_other(word) and word not in persons_set]

        # Capitalize acronyms
        for word in q_matches:
            row['Question'] = row['Question'].replace(word, word.upper())

        for word in a_matches:
            row['Answer'] = row['Answer'].replace(word, word.upper())

         # Capitalize names from persons_df
        for word in q_words:
            if word in persons_set:
                row['Question'] = row['Question'].replace(word, word.title())

        for word in a_words:
            if word in persons_set:
                row['Answer'] = row['Answer'].replace(word, word.title())

    return df



def punc_removal_at_start(input_df):
    """
    This function removes non-alphanumeric characters from the beginning of strings in the 'Question' and 'Answer' columns.

    Args:
        input_df (pd.DataFrame): The input DataFrame.

    Returns:
        pd.DataFrame: A new DataFrame with cleaned 'Question' and 'Answer' columns.
    """
    try:
        # Create a copy of the input DataFrame to avoid modifying the original
        df = input_df.copy()

        # Define a function to clean a single string by removing non-alphanumeric characters
        def clean_text(text):
            if isinstance(text, str):
                # Find and remove non-alphanumeric characters from the beginning of the text
                cleaned_text = re.sub(r'^[^a-zA-Z0-9\s]+', '', text)
                return cleaned_text
            else:
                return text  # Return non-string values as is

        # Apply the clean_text function to the 'Question' and 'Answer' columns
        df['Question'] = df['Question'].apply(clean_text)
        df['Answer'] = df['Answer'].apply(clean_text)

        return df

    except Exception as e:
        print("An error occurred:", str(e))
        
        
        
# Function to format numbers with commas, preserving non-numeric characters
def format_number_with_commas(number_str):
    try:
        # Check if the input is a numeric value
        if isinstance(number_str, (int, float)):
            return locale.format_string("%d", int(number_str), grouping=True)

        # Use regular expression to find and format numbers in the string
        formatted_str = re.sub(r'(\d[\d,]*)', lambda x: locale.format_string("%d", int(x.group(0).replace(',', '')), grouping=True), number_str)
        return formatted_str
    except (ValueError, TypeError):
        return number_str

# Function to format numbers in a DataFrame
def format_numbers_in_dataframe(df):
    df_copy = df.copy()  # Create a copy of the DataFrame to avoid modifying the original
    columns_to_format = ['Question', 'Answer']  # Specify the columns to format
    for column in columns_to_format:
        df_copy[column] = df_copy[column].apply(format_number_with_commas)

    return df_copy
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\rosem\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\rosem\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def main():
    # List of CSV files to process
    start_time = time.time()

    csv_files = [
       # "C:/Users/HP/Documents/Sam/Data Science Voluteer/CSV/Geothermal_energy_wellcome_20230717.csv",
        #"C:/Users/Joshua Giwa/Downloads/QnAs_generated_27_07_2023/Solar power_wellcome_20230717.csv",
        #"C:/Users/Joshua Giwa/Downloads/QnAs_generated_27_07_2023/Solar power_gatesopen_20230717.csv",
        #"C:/Users/Joshua Giwa/Downloads/QnAs_generated_27_07_2023/Geothermal+energy_f1000_20230717.csv",
       # "C:/Users/Joshua Giwa/Downloads/QnAs_generated_27_07_2023/Geothermal_energy_wellcome_20230717.csv",
      #  "C:/Users/Joshua Giwa/Downloads/QnAs_generated_27_07_2023/Carbon+footprint_wellcome_20230717.csv"
      #  "C:/Users/Joshua Giwa/Downloads/test_dataset.csv"
        #"C:/Users/LolaPwasanga/Downloads/datarecords.csv"
       "C:/Users/rosem/Documents/TiiQi/solar_trans_data.csv"
        #'C:/Users/Joshua Giwa/Downloads/QnAs_generated_26_07_2023/QnA_Biomass_f1000_20230717.csv'
       #'/content/test_8086.csv'
        ## Add more file paths here as needed
    ]

    total_questions_count = 0
    total_truncated_questions_count = 0
    total_truncated_answers_count = 0


    for csv_file in csv_files:
        df = pd.read_csv(csv_file)
        # Translate the Q&As in the df to English and return translated df and count
        #df, translated_count, translated_records= translate_to_english(df)

        #print(df.columns)

        #df = add_full_stops(df)

        # Removing any punctuation if any from the start of the answer
        df['Answer'] = df['Answer'].str.replace(r'^[\.\:\- ]*', '', regex=True)     # regex to replace the punctuations from the start of the answer

        # Correcting answers that are truncated in the start of the answer
        df['Answer'] = df['Answer'].apply(correct_truncated_start_word)

       # Load AcronymsFile_2.csv into a DataFrame
        #acronyms_file = 'C:/Users/Joshua Giwa/Downloads/AcronymsFile_2.csv'
        #acronyms_df = pd.read_csv(acronyms_file)

        # Load names_of_persons.csv into a DataFrame
        #persons_file = 'C:/Users/Joshua Giwa/Downloads/names_of_persons.csv'
        #persons_df = pd.read_csv(persons_file)

       # result_df = identify_and_capitalize_acronyms(df, acronyms_df, persons_df)

        #locale.setlocale(locale.LC_ALL, 'en_GB.UTF-8')
        locale.setlocale(locale.LC_ALL, 'en_GB') #modified_ri
        formatted_df = format_numbers_in_dataframe(df)


        #df['Full_Text_URL'] = df['Full_Text_URL'].apply(validate_and_correct_url)

        # corrected_file_path = os.path.join(os.path.expanduser("~"), "Downloads", os.path.basename(csv_file).replace('.csv', '_corrected.csv'))
        #remaining_data_file = os.path.join(os.path.expanduser("~"), "Downloads", os.path.basename(csv_file).replace('.csv', '_remaining_data.csv'))
        #filtered_data_file = os.path.join(os.path.expanduser("~"), "content", os.path.basename(csv_file).replace('.csv', '_filtered_questions_non_optimized.csv'))
        filtered_data_file = os.path.join(os.path.basename(csv_file).replace('.csv', '_filtered_questions_non_optimized.csv')) #modified_riya

        #ammended_space_file = os.path.join(os.path.expanduser("~"), "Downloads", os.path.basename(csv_file).replace('.csv', 'bracket_spaced.csv'))
        #print(filtered_data_file)
        punc_removal_at_start_df = punc_removal_at_start(formatted_df)
        questions_count, truncated_questions, truncated_answers, remaining_data = count_truncated_questions_and_answers_in_df(punc_removal_at_start_df, filtered_data_file)
        comma_cluster_removed_df, total_comma_count = comma_cluster_removal_df(remaining_data)
        space_before_bracket_ammended_df = add_space_before_opening_bracket(comma_cluster_removed_df)
        print("LanguageTool:")
        LanguageTool_corrected_df= LanguageTool_df(space_before_bracket_ammended_df)
        validate_and_correct_url_in_df = validate_and_correct_url_in_dataframe(LanguageTool_corrected_df)



        # Save the processed DataFrame with "updated" added to the name
        cleaned_df =  validate_and_correct_url_in_df.copy()
        cleaned_df_filename = os.path.basename(csv_file).replace('.csv', '_cleaned.csv')

        # Assuming that you have a directory where you want to save the updated DataFrames
        #cleaned_df_dir = os.path.join(os.path.expanduser("~"), "content", "cleaned_QnAs_non_optimized")
        cleaned_df_dir = os.path.join("cleaned_QnAs_non_optimized") #modified_riya

        if not os.path.exists(cleaned_df_dir):
            os.makedirs(cleaned_df_dir)

        cleaned_df_file_path = os.path.join(cleaned_df_dir, cleaned_df_filename)

        # Save the updated DataFrame as a CSV file
        cleaned_df.to_csv(cleaned_df_file_path, index=False, encoding='utf-8')


        # Now, you can use the updated DataFrame for further processing if needed



        total_questions_count += questions_count
        total_truncated_questions_count += truncated_questions
        total_truncated_answers_count += truncated_answers


        print(f"File: {csv_file}\n")
        #print(f"Total translated Q&A: {translated_count}")
        print(f"Total undesirable questions: {questions_count}")
        print(f"Total Truncated Questions: {truncated_questions}")
        print(f"Total Truncated Answers: {truncated_answers}")
       #print(f"Original typo/error found: {original_error_count}")
        print(f"excessive comma occurence: {total_comma_count}")
        #print(f"Corrected typo/error count: {corrected_error_count}")


        print(f"(undesirable_questions + Truncated Questions + Truncated Answers + excessive comma occurence): {questions_count + truncated_questions + truncated_answers +  total_comma_count}\n")

  #  print(f"Total Questions Count: {total_questions_count}")
  #  print(f"Total Truncated Questions Count: {total_truncated_questions_count}")
  #  print(f"Total Truncated Answers Count: {total_truncated_answers_count}")
  #  print(f"Total (Questions + Truncated Questions + Truncated Answers): {total_questions_count + total_truncated_questions_count + total_truncated_answers_count}")

    end_time = time.time()

    elapsed_time_seconds = end_time - start_time
    elapsed_time_minutes = elapsed_time_seconds / 60

    print(f"Script ran for {elapsed_time_minutes:.2f} minutes.")

if __name__ == "__main__":
    main()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3368 entries, 0 to 3367
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        3368 non-null   int64
#  1   Question  3368 non-null   object
#  2   Answer    3330 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 79.1+ KB
# ['id', 'Question', 'Answer']
#
# What kind of short-term support strategies are commonly used for
#
#
# What is the DOI of the article "ISO 14,043
#
#
# How can building integrated photovoltaics (BIPV)
#
#
# What techniques were compared in the statistical and
#
#
# What was the modified collector efficiency increased upto according to Md.R. Al-Mamun et al. Solar Energy 264 (2,023) 111,998
#
#
# What is the purpose of the research paper "Adsorption of gold(III) ions from wastewater using Mg-doped hybrid nanomaterial
#
#
# What parameters were used to calculate the velocity f′(η), temperature θ(η), and entropy generation NG, drag coefficient (Cf),
#
#
# What journal published the article "Economic and greenhouse gas assessments for two hot water industrial systems
#
#
# Who are the authors of the article "Economic and greenhouse gas assessments for two hot water industrial systems
#
#
# What are the different radi
#
#
# What is the paper
#
#
# What is the topic of the paper by
#
#
# What was the increase of production amount of the basin type solar still using
#
#
# What parameters did Joe Patrick Gnanaraj and S. Ramachandran identify that will optimize
#
#
# What is the volume and DOI of the paper published
#
#
# What types of solar hybrid systems are
#
#
# What journal was the article
#
#
# What was the paper by M.Y.H. O
#
#
# What is
#
#
# What was the focus
#
#
# What is
#
#
# What was the
#
#
# How is the stable output of the photovoltaic
#
#
# Who published the paper "Impacts of Compressed Air Energy Storage Plant on an Electricity Market with a Large Renewable
#
#
# What is the purpose of the Moving Spray-Plate Center-
#
#
# Is there evidence of inequality in solar
#
#
# What
#
#
# What is the range of variation from the GHI and PV output estimates in Solar
#
#
# How is LCOE more sensitive to changes in the cost of
#
#
# What does the article
#
#
# What are the cooling methods used for photov
#
#
# What are the temperature variations of the solar panel surface with nanofluid cooling? Answer
#
#
# 0 to 10
#
#
# What
#
#
# What is the transmission efficiency of the clear sky at a sea level solar power farm, according to Eq. (48) in Hottel (1,976) and
#
#
# What type of model did C¸elik and McInnes (
#
#
# What was the purpose of the Technical Report 'Introductory Assessment of Orbiting Reﬂections for Terrestrial Power Generation'
#
#
# What is the energy received by the solar collector per unit collector
#
#
# What is the formula
#
#
# What is the purpose of the article to be published in Renew. Sustain
#
#
# What data was gathered and analyzed in the Financial analysis of Solar Water Heating Systems during the Depression
#
#
# What is ICP
#
#
# What types of infrastructure costs are mentioned in relation to
#
#
# Who mainly borrowed electricity in rural regions of San Juan
#
#
# What is the goal of
#
#
# What is
#
#
# What kind of study was conducted in the article "Differential and persistent risk of excess mortality from Hurricane Maria in Puerto Rico
#
#
# What journal was the article "Differential and persistent risk of excess mortality from Hurricane Maria in Puerto Rico
#
#
# What is the purpose of
#
#
# How did households in rural regions of San Juan Sacatep´equez, Santa Maria de Jesus, La Gomera, and Sipacate charge their phones when borrowing electricity was not an option
#
#
# What source of information was used to track global progress on
#
#
# What are the findings of the República de Guatemala
#
#
# What is the focus
#
#
# What is the loss function factor found to be within the range of 0 and 300 epoch
#
#
# What is the loss function factor found to be within the range of 0 and 300 epoch
#
#
# What is the topic of the SL
#
#
# 2,006+A1
#
#
# What is the main
#
#
# What is
#
#
# What
#
#
# How does the hypotheses and variable structure help evaluate the performance and validity of
#
#
# What is the average national value of Instabhybrid when the wind/solar install ratio is 1
#
#
# What was the study in the J Wind Eng Ind Aerod 1,999;80
#
#
# What was the purpose of the study in Nonlinear Process Geophys 2,008;15
#
#
# What is the purpose of the document "Integrating National Research Agendas on Solar Heat for Industrial Processes 2,020?"
#
#
# What is the primary focus of the article "Installation size, affect, and the social acceptance of renewable energy technologies
#
#
# What is the purpose of the case study discussed in the article An analytical framework for social life cycle impact assessment--part 2
#
#
# What are the beneficial
#
#
# What documents are available on the Covenant of Mayor's website
#
#
# What is demonstrated in this paper about the capability of used PV panels to generate usable amounts of
#
#
# What is the primary
#
#
# What was the technical rooftop solar potential in The
#
#
# Exploring the demographic and socio-economic
#
#
# What is the main focus of the article "Geographies of energy transition
#
#
# How are Ns cells and Np cells connected to achieve the desired voltage and current levels
#
#
# What is the focus of
#
#
# What are the advantages of thin-film based solar panels over
#
#
# What is the aim of the study “Optim
#
#
# What is the ideal approach for overcoming obstacles to renewable
#
#
# Why is energy gaining more and more significance
#
#
# What was the result of the
#
#
# What are the fundamental arithmetic operations
#
#
# What are the technology options for renewable energy based off-grid rural electrification in Uttarakhand state of
#
#
# What is the name of the journal in which
#
#
# In what way does the Solar energy
#
#
# How can China's electricity systems
#
#
# What is the main objective of the China's coal power dec
#
#
# The main search words used to find the hundreds of studies analyzed were
#
#
# The MIVES method consists of three fundamental stages
#
#
# The purpose of the final sensitivity analysis
#
#
# The general formula applied to each DT level is Equation (1)
#
#
# The simplified LCA incorporated into the model is based on ISO 14,040
#
#
# Into
#
#
# Benefits of solar system utilization include energy bill and financial savings via self-sufficiency, governmental policies, incentives, and subsidies, low operation and maintenance cost, building revitalization and the use of vast amounts of unused space, and increased energy security (
#
#
# The main obstacles are considerable energy consumption and carbon footprint during solar cells manufacturing, high subsidized energy price in Iran, public awareness weakness, insufficient national standards & building codes, limited access to
#
#
# The aims of the decision tree model are to provide planning for rooftop alternatives towards better urban air quality, to determine the importance of the indexes, and to rely
#
#
# C3 consists of two indicators
#
#
# The potential data for recycling solar panels is derived from Iranian guidelines (“Environmental, Health and Safety Guideline for Photovoltaic Solar Power Plants, No. 785 Last Edition
#
#
# Into
#
#
# The C4 criterion includes three indicators
#
#
# The parameters and coefficients associated with Indicator I1 are Unit
#
#
# Into
#
#
# Table F.1 and Figs. F.1 and F.2 provide data on the air quality in Tehran, as derived from the 10th Tehran Annual Air and Noise Quality Report.QI categories (Tehran Annual Air and Noise Quality Report, period of March, 2,020 - March 2,021)
#
#
# References used in this article include Abas, Kalair, Khan, Adam, Apaydin, Ahmad Ludin, Alarcon, Aguado, Manga, Josa, and Al-Waeli, Sopian, Kazem, and Chaichan.ppl. Energy
#
#
# The fourth paper mentioned is titled "Performance Evaluation and Techno-Economic Analysis of a Novel Building Integrated PV/T Roof Collector
#
#
# The title of the first article is " 2,021. Techno-economic perspectives of the temperature management of photovoltaic (PV) power plants
#
#
# The title of the article written by Faraca and Astrup in 2,019 is "Plastic waste from recycling centres
#
#
# The DOI of the Solar Cell Efficiency Table (Version 55) is https
#
#
# The DOI of the 2,009 study of Activity-Based Safety Risk Quantification for Concrete Formwork Construction is https
#
#
# The source of information regarding Heating - Fuels & Technologies is the International Energy Agency (IEA).nswer
#
#
# The title of the journal is 'J. Constr. Eng. Manag.'
#
#
# The DOI of the article "ISO 14,043
#
#
# nan
#
#
# PV self-consumption policies are used to provide incentives to promote the adoption of
#
#
# nan
#
#
# The first publication is titled “TOWARDS A NEW INTERACTIVE TOOL OF RESOURCES FOR ACTIVE LEARNING IN UNIVERSITY LARGE GROUPS’ LECTURES.”
#
#
# The last publication is titled “An Improved Fractional Voltage Based MPPT Technique for PV Generation System.”
#
#
# The publication title is "How to make a decision
#
#
# The title of the paper
#
#
# The URL of Tehran Municipality Information and Communication Technology (ICT) Organization is https
#
#
# The title of the journal article published in 2,019 is "Towards Productive Cities
#
#
# The DOI of the study is https
#
#
# nan
#
#
# Stationary flat plate collector (FPC) and single-axis tracking compound parabolic collector (CPC) exhibit thermal efficiencies of 45–60 % (operating range
#
#
# The use of thermal stratification structures, such as diffusers, baffles, membranes, fabrics, etc., is an effective tool to reduce heat losses from the storage tank
#
#
# 5%
#
#
# 32 nm
#
#
# The geometric efficiency observed compared to an ideal CPC for Mexical
#
#
# Several types of absorbing materials were used in the absorber plate such as black paint, copper oxide (CuO), chromium oxide (Cr-Cr2O3), nickel-tin (Ni-Sn), and cobalt oxide (CoO
#
#
# On a daily basis, the average values of thermal efficiency were observed to be 0.46%, 0.45%, 0
#
#
# The geometrical components of CPC are (A) The parabola A, (B) focus of parabola A (FA), (C) axis of parabola A, (D) truncated part of parabola A, (E) parabola B, (F) focus of parabola B (FB), (G) axis of parabola (B), (H) truncated part of parabola B, (I) axis of CPC, (J) aperture of CPC (d1), (K) receiver opening (d2), and (L) acceptance angle (2α).) What is the purpose of the pipe with an opening?nswer
#
#
# nan
#
#
# The experimental result revealed that the black chrome coated copper tube absorber showed a higher absorption coefficient (0.98).l2O3/oil
#
#
# 0.1–0.5 vol% of Al2O3 nanofluid
#
#
# Aluminum oxide (Al2O3), Zinc oxide (ZnO), Iron oxide (Fe2O3), Multiwallcarbon nanotube (MWCNT), Titanium di-oxide (TiO2), Graphene nanoplatelates (GnP), Copper oxide (CuO), Singlewall carbon nanotube (SWCNT), Silicon di-oxide (SiO2), Silver (Ag), Copper (Cu), Carbon nanotube (CNT), Magnesium oxide (MgO), Silicon carbaite (SiC), Sodium Dodecyl Benzene Sulfonate (SDBS),
#
#
# Thinsurat et al.'s 2,019
#
#
# The primary focus of Bellos and Tzivanidis
#
#
# Into
#
#
# Kalogirou’s study in 2,004 (91) focused on Solar thermal collectors and applications
#
#
# Into
#
#
# The article discusses an evacuated tube-parallel plate solar water heater.ppl. Therm. Eng. 37
#
#
# nan
#
#
# The purpose of Lizama-Tzec et al. 2,019 was to investigate the electrodeposition of selective coatings based on black nickel for flatreview on solar energy use in
#
#
# Of the
#
#
# The purpose of the study is to investigate the effect of Al2
#
#
# The focus of the J. Mol. Liq. 377dsorption of gold(III) ions from wastewater using Mg-doped
#
#
# Into
#
#
# The aim of Iranmanesh et al.'s research was to enhance the thermal performance of an evacuated tube solar collector using graphene nanoplatelets nanoflu
#
#
# The main aim of the article is to investigate the efficacy of using ligand-based composite adsorbent for efficient separation, adsorption, and recovery
#
#
# The parameters used to study the heat transmission phenomena are velocity component in x
#
#
# Aziz et al. [6] studied the correlation between carbon pricing and environmental degradation,
#
#
# The difficulties involved in
#
#
# The parabolic trough solar collector system utilizes a mirror in the shape of a parabolic reflector to collect light onto an absorber tube that is positioned at the focus of the parabolic reflector. The concentrated sunlight gets absorbed by a heat transfer
#
#
# Ref. [22] investigated the spectral simulation on the flow patterns and thermal control of radiative nanofluid spraying on an inclined revolving disk
#
#
# The authors considered two types of boundary conditions
#
#
# The equations governing the motion of the viscous non-Newtonian WF model are
#
#
# The equation for determining the nanofluid's electric conductivity is σnf = σf ⎛⎜⎜⎝1 + 3 (σs σf − 1)φ2 + σs σf − (σs σf - 1)φ
#
#
# The key component of engine oil is a blend of
#
#
# The Rosseland Approximation is a mathematical technique commonly used in astrophysics and
#
#
# The radiative flux is represented as qr = − 4σ∗
#
#
# The mathematical partial derivative model is transformed into an invariant ordinary derivative via the similarity variable η(x, y) =
#
#
# The class of polynomials used in the CCSM is known as shifted Chebys
#
#
# The analytic formulation of the SCP BH m(y) of degree m is given by the expression m∑m i=0 (−1)m−v22i
#
#
# Equation (37) is used to solve the system of ODE in equation (16) and (17) by applying equations (16)–(18) as well
#
#
# The MATHEMATICA software was utilized to calculate the velocity f′(η), temperature θ(η), and entropy generation NG, drag coefficient (Cf), and heat transfer rate (Nux). The ranges of influencing parameters utilized were Williamson fluid (WF) parameter (ζ = 0.1 0.2 0.3), permeability parameter (KN = 1 2 3), thermal radiation (RN), Eckert number (Ec= 0
#
#
# The enhanced thermal conductivity of nanofluids enables it to transfer heat more quickly and effectively, leading to an improvement in the system of entropy generation.s a result, the presence of nanoparticles leads to an increase in
#
#
# Into
#
#
# Into
#
#
# The article "Economic and greenhouse gas assessments for two hot water industrial systems
#
#
# The authors of the article "Economic and greenhouse gas assessments for two hot water industrial systems
#
#
# A. Mahmood et al. developed a mathematical model for thermal solar collectors by using magnetohydrodynamic Maxwell nanoflu
#
#
# In the paper on spectral simulation
#
#
# Into
#
#
# Into
#
#
# nan
#
#
# In the study of S. Sindhu and B. Gire
#
#
# The nanomaterials used in the study of magneto-couple stress of tri-hybrid metallic oxide nanomaterials in porous media with nonlinear properties for thermal technology advancement are MWCNT-
#
#
# Into
#
#
# The research paper byccount_circle
#
#
# Low consumption of oil and gas, not polluting the environment, economic growth and development, and low depreciation
#
#
# The maximum and minimum production amounts of drinking water were obtainable using the thick porous fabric on the meshing surface (4.28 L) and the paper on the flat adsorbent surface (2.5 L
#
#
# Into
#
#
# Three types of natural materials were used to increase the evaporation rate in the study
#
#
# The highest distilled water production at 0.1 kg/min for iron ore test is due to the highest light absorbance and lowest trapping incident light of iron ore in comparison to the other materials. Water has more opportunity to exchange heat with iron ore, leading to an increase in the evaporation rate and the production of distilled
#
#
# The highest production price among light-absorbing materials is related to sponge at the highest mass flow rate (0.195 kg/min).n evaporator
#
#
# The title of Kaushal's Renewable and Sustainable Energy Review article is "Solar Stills
#
#
# The goal of the experimental study conducted by Sathyam
#
#
# Shoeibi et al. (2,022) conducted an energy, economic, and environmental analysis of thermoelectric solar desalination systems using cooling fans and found various advantages
#
#
# nan
#
#
# Kumar & Tiwari conducted a life cycle cost analysis of single slope hybrid (PV/T) active solar stills and published their findingsnd P. Surendran, Heat transfer performance of a forced air cooled
#
#
# The paper focuses on the local context of Jordan, where solar energy is abundant throughout the year and how the local residents are responding to the incentives in terms of private solar generation.nswer
#
#
# The Self-Determination Theory suggests that individuals are either intrinsically or extrinsically motivated to behave in specific ways. Intrinsic motivation is the dominant driver when an individual wants to perform a certain act for the internal and personal reward or benefit associated with that act, such as reducing carbon emission, improving
#
#
# To balance the personal needs and implementation of renewable energy in domestic environment in Jordan, a suitable energy policy will be needed to attract further renewable energy
#
#
# The interest in the adoption of renewable energy has been increasing recently due to growing environmental concerns, with 71% of the respondents stating that they ‘strongly agree’, 27% stating that they ‘agree’ and only 2% stating that they ‘strongly disagree’ or
#
#
# The range of household income of the respondents in this study ranges from 400JD to over 3,500JD, with the majority of the respondents earning between 400-999JD, 1,000-1,499JD and 1,500-2,499JD, accounting for 37%, 21% and 17
#
#
# Some of the problematic issues identified by the results were caused by one or more of three factors, which were (a) an item having a weak or negative correlation (r < 0.30) with its total scale, (b) correlation and multicollin
#
#
# The Bollen Stine test (for the overall model) and bootstrapping (confidence intervals for parameter estimates) are
#
#
# According to the analysis, there is a negative and insignificant correlation between Solar Energy Usage and Electrical Bill Burden (-
#
#
# The title of the article discussed in source [6] is “
#
#
# The EMRC can be accessed online at https
#
#
# The research conducted by N. Erős et al. focuses
#
#
# The purpose of J.F. Hair et al.'s 7th Edition of Mult
#
#
# The Jordan Energy Information (2,022) from Enerdata provides information on sources of energy such as electricity, energy market, and
#
#
# This information was reported
#
#
# The main objective of M. Kh
#
#
# The article mentions the A.H. Maslow's theory of human motivation in Psychol. Rev. 50 (4) (1,943) 370 doi
#
#
# The title of the article in [55] is "Experience with Solar Home Systems in Developing Countries
#
#
# The purpose of the paper is to present a novel study in relation to solar energy use in residential dwellings in Jordan to discuss the
#
#
# The benefits of the JREEF include providing 30% of the overall cost of household solar PV, collaborating with local banks to provide citizens with subsidised loans, and enabling 430 mosques and churches, and 138
#
#
# 71% of the respondents stated that they 'strongly agree', 27% stating that they 'agree', and only 2% stating that they 'strongly disagree' or 'neutral' that it is important to use
#
#
# The reasons for respondents purchasing renewable energy systems are shown in Fig. 20. The majority of respondents stated that reducing the electricity bill and enhancing their financial stability were the most important
#
#
# The most important factor
#
#
# The authors declared that there is no conflict of interest including any financial, personal or other relationships with other people or organizations that could inappropriately
#
#
# The title of the paper from [17] is "Emotions towards a mandatory adoption of renewable energy innovations
#
#
# The title of the paper published in Sustain. Cities Soc. is "Assessing the sustainability related concepts of urban development plans in Eastern Europe
#
#
# Into
#
#
# The title of the journal article in [43] is "Assessments of Primary Energy Consumption and its Environmental Consequences in the United Arab Emirates"
#
#
# The aim of the study in [44] is to evaluate the effectiveness of public-private partnership versus extended producer responsibility for end-of-life management of photov
#
#
# The title of the research paper reviewed in [55] is "Experience with Solar Home Systems in Developing Countries
#
#
# The name of the book mentioned in [56] is "SPSS Survival Manual
#
#
# Into
#
#
# The STIRPAT model found empirical evidence to support the hypothesis that urbanization causes increasing energy demand in Pakistan, as outlined in the report by M. Shah
#
#
# Combining PVT and desalination provides an opportunity to identify new integration options for PVT-desalination systems and
#
#
# Coupling solar photovoltaic-thermal (PVT) with desalination could be a practical and immediately deployable route for plausibly more sustainable solar desalination than current solutions. This could catalyze the improvement of the solar energy efficiency, specific energy consumption, and specific water production,
#
#
# An Energy Recovery Device is used to recover the hydraulic potential of brine in seawater reverse osmosis processes by transferring the hydraulic potential to the feed before it flows
#
#
# Into
#
#
# The two main advantages of MD over conventional thermally driven desalination processes are
#
#
# Advanced spectral-splitting PV
#
#
# Luo et al. were able to increase the feed inlet temperature
#
#
# Increasing the temperature leads to enhanced diffusivity and reduced resistance of the membranes to ions, which leads to an increased conductivity of the solution and a reduction of the voltage necessary to maintain the same current. The increased temperature results in a decrease in the
#
#
# Pre-treatment can enable the operation of desalination processes
#
#
# PVT-MED is the use
#
#
# The enhanced operational flexibility of ED is able to reduce substantially the water desalination cost and could enable production of solar-powered ED systems
#
#
# The article discussed in reference 5 is titled, "Energy efficiency of electro-driven brackish water desalination
#
#
# Reference 6 is titled, "Solar desalination" by J. Lienhard, M.A. Antar, A. Bilton, J. Blanco, and G. Zaragoza, and is used to provide an overview of how solar energy can be used
#
#
# Into
#
#
# Solar and Waste Heat Driven Demonstration Plants for Desalination” is to investigate
#
#
# It is titled "Flat-plate PV-thermal Collectors and Systems
#
#
# Into
#
#
# The aim of N.C. Wright and A.G. Winter's study was to
#
#
# Into
#
#
# The article is called "Electrodialysis for Water Desalination
#
#
# The article is titled "Capacitive Deionization TechnologyTM
#
#
# Into
#
#
# Into
#
#
# Spectral beam splitting is a key technology for efficiently converting solar energy because it allows for the selective splitting of solar radiation into different bands based on their wavelengths and then harvesting the energy from
#
#
# Into
#
#
# Into
#
#
# La.-C.le Henaff's paper in 2,021 is titled "Experimental Demonstration of Flexible, Solar-powered Batch Electrodialysis Reversal for Brackish Water Desalination".nswer
#
#
# nan
#
#
# The purpose of the paper
#
#
# Schindler et al. (2,018) suggested that regular irrigation of green roofs in Mediterranean climates could enhance the power output of PV-green roofs.nswer 1
#
#
# The climate of the research site is temperate maritime, with an average maximum day temperature of 22.5 ◦C in July, average global radiation of 393 MJ cm−2yr−1 average precipitation of 880 mm yr−1 and an average Makkink reference crop
#
#
# The reduction in electric efficiency due to the warming up of the panels can be calculated using equation 1
#
#
# Into
#
#
# Into
#
#
# The correlation coefficients are
#
#
# The coefficients for the multi-regression analysis are
#
#
# There is a significant positive non-linear relationship between Delta Ts and Delta Ta (R2
#
#
# The article is analyzing evaporation from (Blue-)Green roofs
#
#
# The source of the article is Water 10 (9) (Sep. 2,018) 1,253 https
#
#
# nan
#
#
# nan
#
#
# nan
#
#
# Green-roof integrated PV canopies provide various benefits for low-income students in the South Bronx such as energy-efficiency, reduced cooling and
#
#
# The main focus of the research outlined in Matthews et al. (2,013) is the variations in photovoltaic performance based on climate and low-slope
#
#
# The paper of A. Jahanfar et al. was published in the journal "Ecol. Eng." in July 2,019
#
#
# Solar-powered sprinkler irrigation integrates the dual advantages of clean energy and high efficient water-saving, which makes it conducive to promoting the development of water and energy saving in agricultural production. It
#
#
# The CAES-SPV sprinkler irrigation system stores energy by gradually compressing air in the closed pressure tank as water is injected in. The energy is released when the internal energy of the air in the tank reaches the critical value and the valve of the tank is opened, converting the internal energy of the air into kinetic energy of the
#
#
# The expansion of compressed air during the energy conversion process affects the hydraulic performance of the spraying process by decreasing the pressure inside the pressure tank, resulting in a decrease in the water released and the micro-element
#
#
# The force F on the water-air boundary is the product of the air pressure and the water-air critical surface area
#
#
# The expansion of the air during the work is represented by Eq. (3)
#
#
# nan
#
#
# The equation used to calculate the uniformity of irrigation is based on the Christiansen uniformity coefficient (Cu), which is calculated using the following formula
#
#
# The corresponding peak water pressures of sprinkler nozzle under the starting pressures of 0.3 0.4 and 0.5 MPa were 0.21 0.30 and 0.34 MPa, respectively, constituting about 68.4–70.1 % of the
#
#
# Linear, exponential, logarithmic and power functions were used to fit the measured nozzle pressure data at the stage of fluctuation decline.nswer
#
#
# When the starting pressure of spraying is 0.3 MPa, the suitable combination spacing of sprinkler nozzles do not exceed 20 m. When the starting pressure is 0.4 MPa, the sprinkler can achieve high spraying uniformity in each combination spacing and pulse spraying time. When the starting pressure of spraying is 0
#
#
# The sprinkler uniformity of the CAES- SP
#
#
# The system sprinkler irrigation uniformity coefficient of the CAES-SPV sprinkler irrigation system remains greater than 88% when the illumination intensity is greater than
#
#
# Compared to solar sprinkler irrigation without energy storage, the CAES-SPV sprinkler irrigation system has a higher wet radius, lower peak
#
#
# The DOI for the paper is "https
#
#
# Into
#
#
# Some current energy storage technologies for electric power applications include pumped hydroelectric storage, compressed air energy storage, and thermal energy storage.SABE 62 (1), 189–202. https
#
#
# Into
#
#
# According to Luo et al. (
#
#
# The DOI for the article "Critical review of energy storage systems" is https
#
#
# Ideal gas reversible volume work is the work done by a gas when its
#
#
# The questions posed are
#
#
# Studies of developing countries tend to find positive influences of income and sometimes education on solar-panel uptake (Lay et al., 2,013; Smith and Urpelainen, 2,014). The results for developed countries are mixed (Balta-Ozkan et al., 2,015; de Groote and Verboven, 2,019;
#
#
# The paper considers four large Australian household surveys from the Australian Bureau of Statistics (ABS)
#
#
# Into
#
#
# Into
#
#
# There is some evidence to suggest that solar panel access growth for younger respondents is slower than it is for older respondents. Additionally, there is also evidence that renters dealing with a real estate agent are disadvantaged when it comes to access to solar panels when compared to othernswer
#
#
# The supplementary data to this article help provide additional information to support the findings of the paper.gric. Res. 1 23 https
#
#
# The review conducted by
#
#
# The Australian Government provides a range of rebates and assistance for clean energy technologies to help reduce the cost of energy bills for households
#
#
# This paper provides an analysis of the complex relationships between energy equity, renewable energy access, and climate change, which is relevant to the current research in this field.doption? Evidence from a natural experiment in Japan. Energy Policy 137
#
#
# de Groote and Verboven's study found that incentives of the Japanese Bank of Investment (BOI
#
#
# Andrea Chareunsy's primary research interests are inequality and sustainable development, in areas relating to
#
#
# The assumptions and inputs used to deconstruct and compare the PPA model of the national regulator included the project-level modelling to simulate PPA/LCOE for 130 districts in the country, a low PPA price of 3.30 USc/kWh, and the possible easing in the PPA-prices by adjusting the form of financing (cost, proportion, and debt tenor).nswer 2
#
#
# Approximately 60% of energy is sourced from expensive imported fossil fuels including R-LNG (24%), furnace oil (14%), natural gas (11%), and coal (10%).nswer 1
#
#
# Over the past three decades, over 92% of the capacity added (i.e. 15.6 GW) has been added
#
#
# The three major steps performed by this paper are to validate if the key parameters, methodological assumptions, computed PPA, and LCO
#
#
# The table below summarizes the general description of all five projects including location, sponsors, PPA period and project basis, solar module, and inverter vendors and technologies, total project cost, recurring
#
#
# The modifications made to the LCOE method are (i) terminal or residual value and depreciation are not included as USS projects are operating on built-own-operate (B
#
#
# Into
#
#
# The average project cost of the projects is USD 0.659 Mn/MW which is below the IRENA reported mean cost of USD 0.995 Mn/MW. The mean project cost for India is USD 0.618 Mn/MW,
#
#
# nan
#
#
# Securitization can help local lenders to off-load their balance sheets and free-up more capital for
#
#
# The researchers zoomed in on the investment case of USS by mapping the location-specific price (PPA tariff) and cost (LCOE) for 130 locations across the country – drawn on detailed project-level financial modelling and
#
#
# The average PPA Tariff (USc) is 3.84 and the average LCOE (USc) isqeeq et al. Energy Economics 122 (2,023) 106,696
#
#
# The average PPA-Tariff in the districts mentioned in the passage is 4.380 USc.nalyzing the
#
#
# The macroeconomic impacts of electricity on economic development are wide-ranging. Electric
#
#
# The focus of the Dawn-ePaper, Sep 20 2,016 article is the impact of payment cuts on solar scale
#
#
# Socio-technical dynamics play a crucial role in low-carbon transitions, as they refer to the interactions between changes in the social organization of technical systems and the underlying
#
#
# The primary source being cited in this paragraph is Gross, R., Blyth, W., Heptonstall, P. (2,010)
#
#
# Sources of information relatable to the review of energy and power planning and policies of
#
#
# In 2,010 Sadorsky found that
#
#
# Surana and Anadon (2,015) analyze two different approaches to
#
#
# Into
#
#
# The role of foreign direct investment in the clean energy consumption of BRICS countries is to create asymmetric effects that can positively influence the consumption
#
#
# Into
#
#
# The benefits of using nanofluids as a cooling medium in solar panels include enhanced heat transfer properties, increased thermal conductivity, specific heat capacity, and improved optical properties. Additionally, nanofluids are capable of transferring heat more quickly and distributing it more efficiently between the nanoparticles and the base fluid, resulting in a decreased temperature
#
#
# The experiments conducted were for a duration of 5 hours in a day, to determine the maximum temperature and power generated from solar panel, using two different cooling fluids
#
#
# The maximum power output of the solar panel is calculated using equation (1)
#
#
# Into
#
#
# The enhanced thermal conductivity of cooling fluids with aluminum
#
#
# Significant temperature reduction between 10°C and 15°C is attributed to the use of different nanofluids to cool a PV solar cell. This improvement can be attributed to the high thermal conductivity of aluminum nanoparticle and the enhanced heat distribution within the fluid due
#
#
# 0 to 10
#
#
# The superior solar efficiency of
#
#
# The primary goal of using air cooled heat sinks for photovoltaic panels is to improve the efficiency
#
#
# The DOI for the Energy 28 (1) (2,003) article is https
#
#
# The title of
#
#
# The reference link of the publication is https
#
#
# The comparison figure of the solar panel efficiency is Figure 6 which shows the comparison of (a) the solar
#
#
# Into
#
#
# The DOI for the paper by Carrillo et al is https
#
#
# The paper by Gad et al evaluated the performance of a direct and indirectccount_circle
#
#
# Fraas (2,012) and Fraas et al. (2,013) introduced a physically-based approach that included geometric losses and atmospheric losses according to
#
#
# The position in the ECI frame is projected in the topocentric horizon frame by a transformation matrix such that (Curtis, 2,013)
#
#
# The elevation can be calculated using Eq. (20)
#
#
# We can determine if the reﬂector is in penumbra or umbra by defining a vector, d ¼ XECI   Xpr, and if jj d jj is smaller than np or nu in Fig
#
#
# The effective area of a solar power farm is the portion of the farm that is illuminated and can be used for electricity generation.nswer
#
#
# The fzero function is used to solve equations and to select initial conditions for the calculation of the exact time point (within the numerical tolerance) for tb or ta.nswer
#
#
# The unit Sun vector in equatorial coordinates is expressed as
#
#
# Into
#
#
# Into
#
#
# This results in an initial argument of latitude of the pass being ho = -29
#
#
# The proﬁle in Fig. 13 is more skewed compared to its polar orbit counterpart in Fig. 12. All three geometric cases appear in the proﬁle. However, the highest quantity of power is delivered around the transition
#
#
# The quantity of energy delivered is equal to 34.7 MWh for the Sun-synchronous orbit, which is close to but smaller than the polar orbit cases considered in the previous subsection. However, the maximum quantity of power delivered is higher in the Sun-synchronous orbit than in the polar orbit, but the area
#
#
# Into
#
#
# Installing the SWH system would result in the avoidance of approximately 58.7 tonnes of carbon dioxide (CO2) emissions annually in
#
#
# The majority of the total installed capacity of solar thermal heat systems by the end of 2,020 was installed in China and Europe
#
#
# Ghana is facing several environmental, economic, and social problems due to its lack of renewable energy sources, such as high energy costs, limited access to electricity, and rising GHG emissions
#
#
# The
#
#
# nan
#
#
# Into
#
#
# The BCR of the SWH system is estimated by using Eq. (7)
#
#
# The Solar Performance Measure to identify the fraction of the heat energy required by
#
#
# The SWH system IRR ranges from 16% to 20.5% across Accra, Cape Coast, Kumasi, Tamale, and Wa.nswer
#
#
# Campaigns can be used to highlight the cost savings, environmental advantages, and
#
#
# The estimated savings potential from deploying the SWH system in
#
#
# The title of the article written by S. Singh et al. is "Technical, Financial, and Environmental Feasibility of Solar Water Heater for Residential, Commercial, and Industrial Application
#
#
# nan
#
#
# The purpose of the Market Report on Solar Thermal Water Heating and Drying of Agricultural Products Soltrain West Africa is to provide an analysis of the solar thermal markets in Ghana and recommend strategies to make the solar thermal sector more accessible and profitable for both the industry and consumers
#
#
# The title of the study conducted by F. Odoi-Yorke, J. John, and L. Atepor is "Composite Decision-Making Algorithms for Optimisation of Hybrid Renewable Energy Systems
#
#
# The Ghana Renewable Energy Master Plan can be accessed at https
#
#
# The data analyzed in the Financial Analysis of Solar Water Heating Systems during the Depression
#
#
# The main objective of
#
#
# The ratio of attrition media to sample is set as 2
#
#
# The ore separation degree of the Mo-Glass curve is positive and the cut point 1,180 µm yields the maximum ore separation degree where |ηore,Mo-Glass,max| is 16.26% and 65 wt% Mo
#
#
# Compared to another thin-film material, lithium-ion batteries, whose valuable metal concentrate in fine size fractions [29], functional materials in thin-film
#
#
# Through grinding, 82.64 w% of indium can be concentrated in the size fraction less than 38 μm. Additionally, 13.7 g of fine particles can be obtained from 500 g sample and 200 g attrition media with 1,506 ppm indium, 482 ppm gallium and 1,589 ppm molybdenum
#
#
# Equipment used includes a Cutting Mill (SM 200 smf, Retsch GmbH, Haan, Germany, serial No. 12,102,906,103), an Oven (NCD-120 NASER, Dongguan, China, serial No. YJ20,180,525,002), Sieves (Laboratory Test Sieve
#
#
# Into
#
#
# The title of the paper written by Chowdhury et al. is “An Overview of Solar Photovoltaic Panels’ End-of-Life Material
#
#
# Into
#
#
# The communities were selected for study based on
#
#
# A favorable photovolt
#
#
# The researchers used a self-administered questionnaire to collect quantitative data on four primary topics
#
#
# Studies have shown that access to energy is linked to poverty and human development, as economically poor communities are usually the last to gain access to electricity under both initial electrification and disaster recovery efforts. Additionally, energy access has been recognized as an important precursor to elevating economic mobility, with studies emphasizing that economic development comes after energy
#
#
# Into
#
#
# Guatemalan residents were primarily interested in using their solar kits for lighting (61%),
#
#
# The Solar Kit cannot power larger appliances such as a full-size refrigerator which requires over 1 kWh/day nor can it power high-load devices for long durations such as a sewing machine, lap top charging or mini-fridges which require up to 388-776 Wh/day after
#
#
# Some of the consequences of energy poverty include an increase in time used for collecting fuel sources, food, medical care, and other resources, which often require extensive travel for individuals in rural or remote areas, and a lack of
#
#
# Access to electricity can reduce energy burdens and provide direct benefits across many sectors, such as improvements in education, safety, health, and leisure. Lighting after dark impacts safety at night, study time and school performance for students, and leisure activities that promote mental health
#
#
# The International Energy Agency's (IEA) Access to Electricity – SDG7
#
#
# nan
#
#
# nan
#
#
# nan
#
#
# The World Bank has found that economic mobility across generations varies from country to country, with some areas having greater levels of economic mobility while other areas have less.ccess to energy as a human right
#
#
# The article "Differential and persistent risk of excess mortality from Hurricane Maria in Puerto Rico
#
#
# nan
#
#
# Into
#
#
# The two communities that experience energy poverty examined in this study are households in rural or remote regions of Guatemala who do not have existing access to electricity and households in remote regions of Puerto Rico whose homes were previously
#
#
# Regions that are predominantly rural, remote, impoverished, or have a high indigenous population are most disproportionately in need of
#
#
# Analysis of Table S2 can provide estimates on which devices can and cannot be operated by different solar kit systems, as well as provide values for system capacity and daily device power consumption. Additionally, the values allow for detailed technical analysis on load profiles (PV output,
#
#
# Into
#
#
# Households reported a decline in quality of life due to the lack of electricity in the following topics
#
#
# B.M.S and W.K.D. conceived the
#
#
# Organizations thanked for making this work possible include Fundación MEME, House of Hope, Viván Los Jóvenes, the Puerto Rico Solar Health Study Group, the Clean Energy Group, the Clean Energy Institute at the University of Washington, and all members of Global Renewables Infrastructure Development (
#
#
# Into
#
#
# The book Field Actions Science Reports (FACTS) focuses on decentralized electrification
#
#
# The title of the 2,015 technical report is "Beyond Connections
#
#
# The title of the
#
#
# nan
#
#
# The Republic of Guatemala
#
#
# The publication of Global energy assessment - Toward a sustainable future is Cambridge
#
#
# nan
#
#
# Energy poverty is characterized by a lack of access to reliable and affordable
#
#
# Román et al. (2,019) conducted a satellite-based assessment of electricity restoration efforts in Puerto Rico after Hurricane Maria.mericans’ viewsmericans-views-on-energy-sources-climate-change-and-energy-policies/
#
#
# Into
#
#
# The peak sun hour analysis of energy systems measures the number of hours of available sunlight at the peak
#
#
# The World Bank provides an overview of poverty that emphasizes the global varied nature of poverty
#
#
# DL techniques can improve accuracy of forecasting methods, as well as help to predict soil or dust factors in time-series forecasting solutions, making it easier to predict future energy production for large-scale solar
#
#
# RNN can be used to analyze time-series data for the forecast trend of solar radiation.nswer
#
#
# Error metrics used to evaluate solar forecasting models include root mean square error (RMSE), mean absolute error (MAE), mean absolute percentage error (MAPE), and normalized root mean square error (NR
#
#
# The predictions of the solar forecast model are evaluated by comparing them to the expected outcomes and analyzing their accuracy.re then compared to the actual performance of the model
#
#
# The hypotheses and variable structure play a crucial role in defining the variables to be included in the solar forecast model and their relationships with each other. It provides the framework to capture the relevant factors that influence solar energy production and forecasting accuracy. It also helps to determine which variables are used as inputs, which are considered as outputs,
#
#
# Combining both physical and data-driven models can improve the accuracy of solar forecasts.nswer
#
#
# The mathematical equation for a single neuron in a feed forward neural network can be expressed as
#
#
# The mathematical equation for an LSTM layer can be expressed as
#
#
# The process
#
#
# The dataset split into training and testing sets with a ratio of 100
#
#
# The CNN-LSTM hybrid model is considered an optimal model for SEVs forecasting because it can guarantee accurate predictions for a variety of LSSPs
#
#
# The range of the training and validation performance metrics error loss is from 1.0 to 0.0.tion for that particular time frame. The second graph repre-
#
#
# The true and actual values of the
#
#
# The range of error loss performance metrics for training and validation ranges from 1.1 to 0.5.nswer
#
#
# nan
#
#
# The RNN model is not an optimal model for any of the solar parameters based on the analysis of performance error metrics, and it showed a not very accurate value for SEVs. Therefore, it cannot be considered as an optimal model
#
#
# The values obtained for power generation, PR, and soiling loss were 611,188 0.385 and 0.2,347 for RMSE, 220.790 0.4,358 and 0.9,511 for MAE, 0.135 0.28,478 and 0.127 for MAPE, and 2.20
#
#
# The methodology proposed by Perez-Higueras, E.F. Fernandez, L. and Hontoria is based on dynamic artificial neural network and is used for short-term forecasting of the power
#
#
# Ghritlahre and Prasad used multi-layer perceptron (MLP), generalized regression neural network (GRNN) and radial basis function (RBF) models of artificial neural network (ANN) technique to
#
#
# DL techniques can improve accuracy of forecasting methods, as well as help to predict soil or dust factors in time-series forecasting solutions, making it easier to predict future energy production for large-scale solar
#
#
# RNN can be used to analyze time-series data for the forecast trend of solar radiation.nswer
#
#
# Error metrics used to evaluate solar forecasting models include root mean square error (RMSE), mean absolute error (MAE), mean absolute percentage error (MAPE), and normalized root mean square error (NR
#
#
# The predictions of the solar forecast model are evaluated by comparing them to the expected outcomes and analyzing their accuracy.re then compared to the actual performance of the model
#
#
# The hypotheses and variable structure play a crucial role in defining the variables to be included in the solar forecast model and their relationships with each other. It provides the framework to capture the relevant factors that influence solar energy production and forecasting accuracy. It also helps to determine which variables are used as inputs, which are considered as outputs,
#
#
# Combining both physical and data-driven models can improve the accuracy of solar forecasts.nswer
#
#
# The mathematical equation for a single neuron in a feed forward neural network can be expressed as
#
#
# The mathematical equation for an LSTM layer can be expressed as
#
#
# The process
#
#
# The dataset split into training and testing sets with a ratio of 100
#
#
# The CNN-LSTM hybrid model is considered an optimal model for SEVs forecasting because it can guarantee accurate predictions for a variety of LSSPs
#
#
# The range of the training and validation performance metrics error loss is from 1.0 to 0.0.tion for that particular time frame. The second graph repre-
#
#
# The true and actual values of the
#
#
# The range of error loss performance metrics for training and validation ranges from 1.1 to 0.5.nswer
#
#
# nan
#
#
# The RNN model is not an optimal model for any of the solar parameters based on the analysis of performance error metrics, and it showed a not very accurate value for SEVs. Therefore, it cannot be considered as an optimal model
#
#
# The values obtained for power generation, PR, and soiling loss were 611,188 0.385 and 0.2,347 for RMSE, 220.790 0.4,358 and 0.9,511 for MAE, 0.135 0.28,478 and 0.127 for MAPE, and 2.20
#
#
# The methodology proposed by Perez-Higueras, E.F. Fernandez, L. and Hontoria is based on dynamic artificial neural network and is used for short-term forecasting of the power
#
#
# Ghritlahre and Prasad used multi-layer perceptron (MLP), generalized regression neural network (GRNN) and radial basis function (RBF) models of artificial neural network (ANN) technique to
#
#
# The findings and information generated from this numerical techniques helps managers prioritise interventions and implement targeted measures to mitigate negative social impacts. They are of significance to SLC
#
#
# Subramanian & Yung conducted an audit application on desktop computers and another application in the construction industry with more thorough critical insight than similar method types documented in SLCA studies.nswer 1
#
#
# Into
#
#
# 2,006+A1
#
#
# Into
#
#
# The DOI of the study is https
#
#
# Into
#
#
# Some examples of studies that use the Social Life Cycle Assessment (S-LCA) method include the Social Life Cycle Assessment of Microalgae-based Systems forppliances in Thailand. J Ind Ecol 2,020;24(7)
#
#
# Into
#
#
# The Sustainable Energy Action Plan (SEAP) is a plan designed by the Municipality to contain a clear outline of the strategy and relative actions to be taken by the local authority to reach its commitments in 2,020 in terms of sustainability goals set by EU 20
#
#
# Projections to 2,030 scenarios can be done mainly in two ways
#
#
# Benedetto Nastasi's PhD dissertation is focused on the eco-fuels and the transition within energy planning and management at building, district and national scale towards decarbonization
#
#
# The title of the paper is "How high albedo and traditional buildings’ materials and vegetation affect the quality of urban microclimate
#
#
# The paper discusses the beneficial effects of retroreflective materials
#
#
# The title of the publication of Larsen K. is "End-of-life PV
#
#
# The four solar energy variables used in the TDL forecasting models in this study
#
#
# The performance error indicators used to identify the forecast results of ANN, CNN-SLTM, and RNN models are root mean square error (RMSE), mean bias error (MBE), mean absolute percentage error (MAPE), and
#
#
# nan
#
#
# Potential sources of error or complexity are identified by examining the various components of the model, such as the algorithms and mathematical equations used, to determine how different variables and factors may affect
#
#
# Into
#
#
# nan
#
#
# Soiling loss, which is the accumulation of dust, dirt, or mud on the surface of the panel, is considered a very important loss to estimate for PV
#
#
# The mathematical equation for a single neuron in a feed forward neural network is expressed as
#
#
# The steps involved in the forecasting model based on ANN, RNN and CNN-LSTM are
#
#
# The dataset used in the process was split into training and testing sets with a ratio of 100
#
#
# ...
#
#
# What is the name of the journal in which
#
# Truncated Question 3250: What is the name of the journal in which
#
# nan
#
# Corresponding Question 3250: What is the name of the journal in which
# Truncated Answer  3250: nan
#
#
# In what way does the Solar energy
#
#
# In what way does the Solar energy
#
# Truncated Question 3252: In what way does the Solar energy
#
# The Solar energy
#
# Corresponding Question 3252: In what way does the Solar energy
# Truncated Answer  3252: The Solar energy
#
#
# Natural gas and oil affect resource curse in Russia by competing with each other as fossil fuel sources,
#
#
# Natural gas and oil affect resource curse in Russia by competing with each other as fossil fuel sources,
#
# Corresponding Question 3256: How do natural gas and oil affect resource curse in Russia?
# Truncated Answer  3256: Natural gas and oil affect resource curse in Russia by competing with each other as fossil fuel sources,
#
#
# nan
#
#
# nan
#
# Corresponding Question 3258: What is the numerical investigation of a new combined energy cycle based on Miller cycle, Organic Rankine cycle, Stirling engine and alkaline fuel cell?
# Truncated Answer  3258: nan
#
#
# Factors that have been shown to influence the diffusion of solar energy usage in Hong Kong include the cost of solar energy equipment, access to information
#
#
# Factors that have been shown to influence the diffusion of solar energy usage in Hong Kong include the cost of solar energy equipment, access to information
#
# Corresponding Question 3260: What factors have been shown to influence the diffusion of solar energy usage in Hong Kong?
# Truncated Answer  3260: Factors that have been shown to influence the diffusion of solar energy usage in Hong Kong include the cost of solar energy equipment, access to information
#
#
# The authors of this article are Spiru Paraschiv, Nicoleta B˘arbu¸t˘a-Mi¸su, and Liz
#
#
# The authors of this article are Spiru Paraschiv, Nicoleta B˘arbu¸t˘a-Mi¸su, and Liz
#
# Corresponding Question 3267: Who are the authors of this article?
# Truncated Answer  3267: The authors of this article are Spiru Paraschiv, Nicoleta B˘arbu¸t˘a-Mi¸su, and Liz
#
#
# The cost estimation guideline for solar PV network installation in smart cities depends on various factors, such as the size of the project, the type of system components
#
#
# The cost estimation guideline for solar PV network installation in smart cities depends on various factors, such as the size of the project, the type of system components
#
# Corresponding Question 3271: What is the cost estimation guideline for solar PV network installation in smart cities?
# Truncated Answer  3271: The cost estimation guideline for solar PV network installation in smart cities depends on various factors, such as the size of the project, the type of system components
#
#
# nan
#
#
# nan
#
# Corresponding Question 3273: What is the aim of the paper?
# Truncated Answer  3273: nan
#
#
# The benefits of wind power as a renewable and clean energy source include environmental, economic, and social benefits, and help to reduce dependency on nonrenewable fuels such
#
#
# The benefits of wind power as a renewable and clean energy source include environmental, economic, and social benefits, and help to reduce dependency on nonrenewable fuels such
#
# Corresponding Question 3280: What are the benefits of wind power as a renewable and clean energy source?
# Truncated Answer  3280: The benefits of wind power as a renewable and clean energy source include environmental, economic, and social benefits, and help to reduce dependency on nonrenewable fuels such
#
#
# The aim of the study conducted by Spiru Paraschiv, Nicoleta B˘arbu¸t˘a-Mi¸su, and Lizica Simona Paraschiv was to analyze the technical and economic aspects of a solar air heating system integrationvailability study of grid parity for rooftop solar photovoltaics in India. Energies 2,021;14
#
#
# The aim of the study conducted by Spiru Paraschiv, Nicoleta B˘arbu¸t˘a-Mi¸su, and Lizica Simona Paraschiv was to analyze the technical and economic aspects of a solar air heating system integrationvailability study of grid parity for rooftop solar photovoltaics in India. Energies 2,021;14
#
# Corresponding Question 3305: What is the aim of the study conducted by Spiru Paraschiv, Nicoleta B˘arbu¸t˘a-Mi¸su, and Lizica Simona Paraschiv?
# Truncated Answer  3305: The aim of the study conducted by Spiru Paraschiv, Nicoleta B˘arbu¸t˘a-Mi¸su, and Lizica Simona Paraschiv was to analyze the technical and economic aspects of a solar air heating system integrationvailability study of grid parity for rooftop solar photovoltaics in India. Energies 2,021;14
#
#
# How can China's electricity systems
#
#
# How can China's electricity systems
#
# Truncated Question 3308: How can China's electricity systems
#
# Into
#
# Corresponding Question 3308: How can China's electricity systems
# Truncated Answer  3308: Into
#
#
# What is the main objective of the China's coal power dec
#
#
# What is the main objective of the China's coal power dec
#
# Truncated Question 3311: What is the main objective of the China's coal power dec
#
# Into
#
# Corresponding Question 3311: What is the main objective of the China's coal power dec
# Truncated Answer  3311: Into
#
#
# Abbreviations commonly used for machine learning algorithms include ANN (Artificial Neural Network), DT (Decision Tree), ML (Machine Learning), RF (Random Forest), SVR (Support Vector Regression), and XGBOOST (Extreme
#
#
# Abbreviations commonly used for machine learning algorithms include ANN (Artificial Neural Network), DT (Decision Tree), ML (Machine Learning), RF (Random Forest), SVR (Support Vector Regression), and XGBOOST (Extreme
#
# Corresponding Question 3319: What are the abbreviations used for machine learning algorithms?
# Truncated Answer  3319: Abbreviations commonly used for machine learning algorithms include ANN (Artificial Neural Network), DT (Decision Tree), ML (Machine Learning), RF (Random Forest), SVR (Support Vector Regression), and XGBOOST (Extreme
#
#
# By using machine learning algorithms for solar energy forecasting, advantages such as enhanced accuracy, scalability, and efficiency can be achieved.rtificial neural network (ANN) for predicting the monthly solar
#
#
# By using machine learning algorithms for solar energy forecasting, advantages such as enhanced accuracy, scalability, and efficiency can be achieved.rtificial neural network (ANN) for predicting the monthly solar
#
# Corresponding Question 3321: What are the advantages of using machine learning algorithms for solar energy forecasting?
# Truncated Answer  3321: By using machine learning algorithms for solar energy forecasting, advantages such as enhanced accuracy, scalability, and efficiency can be achieved.rtificial neural network (ANN) for predicting the monthly solar
#
#
# The aim of this work is to establish a comprehensive study of forecasting the energy production of solar panels, by training, testing, and comparing six well-known ML models and
#
#
# The aim of this work is to establish a comprehensive study of forecasting the energy production of solar panels, by training, testing, and comparing six well-known ML models and
#
# Corresponding Question 3323: What is the focus of this work?
# Truncated Answer  3323: The aim of this work is to establish a comprehensive study of forecasting the energy production of solar panels, by training, testing, and comparing six well-known ML models and
#
#
# El Maghraoui et al. (2,022) used four ML algorithms to predict energy consumption in open-pit mines
#
#
# El Maghraoui et al. (2,022) used four ML algorithms to predict energy consumption in open-pit mines
#
# Corresponding Question 3324: What ML algorithms were used by El Maghraoui et al. (2,022) to predict energy consumption in open-pit mines?
# Truncated Answer  3324: El Maghraoui et al. (2,022) used four ML algorithms to predict energy consumption in open-pit mines
#
#
# The study conducted by El Maghraoui et al. (2,022) found that the Random Forest algorithm was the most effective model for
#
#
# The study conducted by El Maghraoui et al. (2,022) found that the Random Forest algorithm was the most effective model for
#
# Corresponding Question 3325: What algorithm was found to be most effective in the study conducted by El Maghraoui et al. (2,022)?
# Truncated Answer  3325: The study conducted by El Maghraoui et al. (2,022) found that the Random Forest algorithm was the most effective model for
#
#
# The purpose of the study proposed by Laayati et al. (2,022
#
#
# The purpose of the study proposed by Laayati et al. (2,022
#
# Corresponding Question 3327: What is the purpose of the study proposed by Laayati et al. (2,022)?
# Truncated Answer  3327: The purpose of the study proposed by Laayati et al. (2,022
#
#
# The predicted energy was evaluated and assessed based on four metrics
#
#
# The predicted energy was evaluated and assessed based on four metrics
#
# Corresponding Question 3333: What metrics were used to evaluate and assess the predicted energy?
# Truncated Answer  3333: The predicted energy was evaluated and assessed based on four metrics
#
#
# XGBoost is an extension of Gradient-boosted Decision Trees (GBDT). It was created specifically to increase speed and effectiveness when predicting solar power with minimal error.nd the response variable (Almutairi et al., 2,019). In solar ener-
#
#
# XGBoost is an extension of Gradient-boosted Decision Trees (GBDT). It was created specifically to increase speed and effectiveness when predicting solar power with minimal error.nd the response variable (Almutairi et al., 2,019). In solar ener-
#
# Corresponding Question 3335: What is XGBoost?
# Truncated Answer  3335: XGBoost is an extension of Gradient-boosted Decision Trees (GBDT). It was created specifically to increase speed and effectiveness when predicting solar power with minimal error.nd the response variable (Almutairi et al., 2,019). In solar ener-
#
#
# Random Forest grows multiple decision trees which are merged together for a more accurate prediction. Additionally, the accuracy of the models is improved when additional input features, such as the solar irradiance and
#
#
# Random Forest grows multiple decision trees which are merged together for a more accurate prediction. Additionally, the accuracy of the models is improved when additional input features, such as the solar irradiance and
#
# Corresponding Question 3337: What does Random Forest do to create a more accurate prediction?
# Truncated Answer  3337: Random Forest grows multiple decision trees which are merged together for a more accurate prediction. Additionally, the accuracy of the models is improved when additional input features, such as the solar irradiance and
#
#
# The prediction performance of the machine learning model is determined using Root mean squared error (re used to collect and transmit information from solar energy
#
#
# The prediction performance of the machine learning model is determined using Root mean squared error (re used to collect and transmit information from solar energy
#
# Corresponding Question 3338: What measures are used to determine the prediction performance of a machine learning model?
# Truncated Answer  3338: The prediction performance of the machine learning model is determined using Root mean squared error (re used to collect and transmit information from solar energy
#
#
# IoT devices can facilitate the integration of solar energy systems with other smart devices by connecting solar panels to smart home systems, allowing homeowners to monitor their energy production and consumption, optimize energy usage, and even sell excess energy back to the grid. Additionally, IoT-based communication between solar
#
#
# IoT devices can facilitate the integration of solar energy systems with other smart devices by connecting solar panels to smart home systems, allowing homeowners to monitor their energy production and consumption, optimize energy usage, and even sell excess energy back to the grid. Additionally, IoT-based communication between solar
#
# Corresponding Question 3342: How can IoT facilitate the integration of solar energy systems with other smart devices and grids?
# Truncated Answer  3342: IoT devices can facilitate the integration of solar energy systems with other smart devices by connecting solar panels to smart home systems, allowing homeowners to monitor their energy production and consumption, optimize energy usage, and even sell excess energy back to the grid. Additionally, IoT-based communication between solar
#
#
# The prediction results of the energy production by the solar site of each algorithm show that the performance of the ANN model confirms the studies done by Rahman et al., Abuella and Chowdhury, Al-Dahidi et al
#
#
# The prediction results of the energy production by the solar site of each algorithm show that the performance of the ANN model confirms the studies done by Rahman et al., Abuella and Chowdhury, Al-Dahidi et al
#
# Corresponding Question 3344: What do the prediction results of the energy production by the solar site of each algorithm show?
# Truncated Answer  3344: The prediction results of the energy production by the solar site of each algorithm show that the performance of the ANN model confirms the studies done by Rahman et al., Abuella and Chowdhury, Al-Dahidi et al
#
#
# When applying the methodology to different situations with different datasets, certain considerations should be taken into account, such as the solar plant configurations, environmental conditions, and other relevant factors. It is also important to note
#
#
# When applying the methodology to different situations with different datasets, certain considerations should be taken into account, such as the solar plant configurations, environmental conditions, and other relevant factors. It is also important to note
#
# Corresponding Question 3348: What considerations should be taken when applying the methodology to different situations?
# Truncated Answer  3348: When applying the methodology to different situations with different datasets, certain considerations should be taken into account, such as the solar plant configurations, environmental conditions, and other relevant factors. It is also important to note
#
#
# The article was featured in the publication "Communications in Computer and Information
#
#
# The article was featured in the publication "Communications in Computer and Information
#
# Corresponding Question 3361: What is the title of the publication that the article was featured in?
# Truncated Answer  3361: The article was featured in the publication "Communications in Computer and Information
#
#
# The title of the paper presented at the 2,021 IEEE PES/IAS PowerAfrica is "Implementing extreme gradient boosting (xg
#
#
# The title of the paper presented at the 2,021 IEEE PES/IAS PowerAfrica is "Implementing extreme gradient boosting (xg
#
# Corresponding Question 3365: What is the title of the paper presented at the 2,021 IEEE PES/IAS PowerAfrica?
# Truncated Answer  3365: The title of the paper presented at the 2,021 IEEE PES/IAS PowerAfrica is "Implementing extreme gradient boosting (xg
#
#
# Sharifzadeh et al. studied three machine-learning methods
#
#
# Sharifzadeh et al. studied three machine-learning methods
#
# Corresponding Question 3367: How many machine-learning methods were studied in Sharifzadeh et al.?
# Truncated Answer  3367: Sharifzadeh et al. studied three machine-learning methods
#
# Number of rows in filtered data: 36
# Number of rows in remaining data: 2787
#
# Original text: The Lifetime Revenue Stream is {ri1 ri2… Riit, Riit+1 Riit+2 ,, Riit+30}.
# Corrected text: The Lifetime Revenue Stream is {ri1 ri2… Riit, Riit+1 Riit+2 ,  Riit+30}.
# Total comma count: 5941378
# LanguageTool:
# 100%|██████████████████████████████████████████████████████████████████████████████| 2787/2787 [04:22<00:00, 10.62it/s]
# File: C:/Users/rosem/Documents/TiiQi/solar_trans_data.csv
#
# Total undesirable questions: 68
# Total Truncated Questions: 87
# Total Truncated Answers: 542
# excessive comma occurence: 5941378
# (undesirable_questions + Truncated Questions + Truncated Answers + excessive comma occurence): 5942075
#
# Script ran for 39.34 minutes.

# %% [markdown]
# ### !jupyter notebook list

# %%
from jupyter_core.paths import jupyter_config_dir
jupyter_dir = jupyter_config_dir()
jupyter_dir
# Out:
# 'C:\\Users\\Joshua Giwa\\.jupyter'
