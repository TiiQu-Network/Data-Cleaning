# %% [markdown]
# ### Counting the total number of all errors including undesirable Typos, QnAs and truncated QnAs

# %%
# !pip install language_tool_python spacy textblob
# Out:
# Requirement already satisfied: language_tool_python in c:\users\joshua giwa\anaconda3\lib\site-packages (2.7.1)
# Requirement already satisfied: spacy in c:\users\joshua giwa\anaconda3\lib\site-packages (3.4.3)
# Requirement already satisfied: textblob in c:\users\joshua giwa\anaconda3\lib\site-packages (0.17.1)
# Requirement already satisfied: requests in c:\users\joshua giwa\anaconda3\lib\site-packages (from language_tool_python) (2.25.1)
# Requirement already satisfied: tqdm in c:\users\joshua giwa\anaconda3\lib\site-packages (from language_tool_python) (4.59.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\joshua giwa\anaconda3\lib\site-packages (from spacy) (3.0.6)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\joshua giwa\anaconda3\lib\site-packages (from spacy) (1.0.6)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in c:\users\joshua giwa\anaconda3\lib\site-packages (from spacy) (0.4.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\joshua giwa\anaconda3\lib\site-packages (from spacy) (2.0.6)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\joshua giwa\anaconda3\lib\site-packages (from spacy) (1.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\joshua giwa\anaconda3\lib\site-packages (from spacy) (21.3)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\joshua giwa\anaconda3\lib\site-packages (from spacy) (0.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in c:\users\joshua giwa\anaconda3\lib\site-packages (from spacy) (3.0.10)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\joshua giwa\anaconda3\lib\site-packages (from spacy) (2.0.6)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in c:\users\joshua giwa\anaconda3\lib\site-packages (from spacy) (8.1.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in c:\users\joshua giwa\anaconda3\lib\site-packages (from spacy) (0.10.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\joshua giwa\anaconda3\lib\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\joshua giwa\anaconda3\lib\site-packages (from spacy) (2.4.5)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\joshua giwa\anaconda3\lib\site-packages (from spacy) (1.0.1)
# Requirement already satisfied: jinja2 in c:\users\joshua giwa\anaconda3\lib\site-packages (from spacy) (2.11.3)
# Requirement already satisfied: setuptools in c:\users\joshua giwa\anaconda3\lib\site-packages (from spacy) (52.0.0.post20210125)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\joshua giwa\anaconda3\lib\site-packages (from spacy) (1.20.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\joshua giwa\anaconda3\lib\site-packages (from packaging>=20.0->spacy) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in c:\users\joshua giwa\anaconda3\lib\site-packages (from pathy>=0.3.5->spacy) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\joshua giwa\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.1.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\joshua giwa\anaconda3\lib\site-packages (from requests->language_tool_python) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\joshua giwa\anaconda3\lib\site-packages (from requests->language_tool_python) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\joshua giwa\anaconda3\lib\site-packages (from requests->language_tool_python) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\joshua giwa\anaconda3\lib\site-packages (from requests->language_tool_python) (2.10)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\joshua giwa\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\joshua giwa\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.0.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\joshua giwa\anaconda3\lib\site-packages (from typer<0.8.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: nltk>=3.1 in c:\users\joshua giwa\anaconda3\lib\site-packages (from textblob) (3.6.1)
# Requirement already satisfied: joblib in c:\users\joshua giwa\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (1.1.0)
# Requirement already satisfied: regex in c:\users\joshua giwa\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (2021.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\joshua giwa\anaconda3\lib\site-packages (from jinja2->spacy) (1.1.1)

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.4.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.4.1/en_core_web_sm-3.4.1-py3-none-any.whl (12.8 MB)
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in c:\users\joshua giwa\anaconda3\lib\site-packages (from en-core-web-sm==3.4.1) (3.4.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\joshua giwa\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\joshua giwa\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.6)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\joshua giwa\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.6)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in c:\users\joshua giwa\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (8.1.5)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\joshua giwa\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.6.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\joshua giwa\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.3.0)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\joshua giwa\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.20.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in c:\users\joshua giwa\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.10)
# Requirement already satisfied: setuptools in c:\users\joshua giwa\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (52.0.0.post20210125)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\joshua giwa\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.59.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\joshua giwa\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.25.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\joshua giwa\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.6)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\joshua giwa\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\joshua giwa\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.4.5)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in c:\users\joshua giwa\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.4.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\joshua giwa\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.8.2)
# Requirement already satisfied: jinja2 in c:\users\joshua giwa\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.11.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\joshua giwa\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (21.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in c:\users\joshua giwa\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.10.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\joshua giwa\anaconda3\lib\site-packages (from packaging>=20.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in c:\users\joshua giwa\anaconda3\lib\site-packages (from pathy>=0.3.5->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\joshua giwa\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\joshua giwa\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\joshua giwa\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\joshua giwa\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\joshua giwa\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.26.4)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\joshua giwa\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.0.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\joshua giwa\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\joshua giwa\anaconda3\lib\site-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\joshua giwa\anaconda3\lib\site-packages (from jinja2->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.1.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import pandas as pd
import os
import csv
import re
import language_tool_python
import time
import cProfile
from textblob import TextBlob
import spacy
from urllib.parse import urlparse, urlunparse
import locale
import nltk
from nltk.corpus import stopwords
import re



def count_multiple_commas(text):
    if isinstance(text, str):
        pattern = re.compile(r',{2,}')
        return len(re.findall(pattern, text))
    else:
        return text

def replace_multiple_commas(text):
    if isinstance(text, str):
        pattern = re.compile(r',{2,}')
        corrected_text = re.sub(pattern, ', ', text)
        if corrected_text != text:
            print(f"\nOriginal text: {text}")
            print(f"Corrected text: {corrected_text}")
        return corrected_text
    else:
        return text

def comma_cluster_removal_df(df):
    total_comma_count = 0

    for column in df.columns:
        df[column] = df[column].apply(replace_multiple_commas)
        total_comma_count += df[column].apply(count_multiple_commas).sum()

    print(f"Total comma count: {total_comma_count}")
    return df, total_comma_count


def is_undesirable_question_to_count(question):
    if isinstance(question, str):
        count_phrases = [
            
            "what is the title",
            "what is the research topic",
            "what data is used in the study",
            "what data sets are collected in this study",
            "how did the study",
            "what does the arrow in figure 6 represent",
            "what was the publication date of the study",
            "what is the title of the paper",
            "what is the purpose of this study",
            "what was the goal of the study",
            "what data was utilized in the study",
            "what is the source of funding for this study",
            "what was the aim of this study",
            "what are the objectives of the study",
            "what was the main focus of the study",
            "what were the main conclusions of the study",
            "what methods were used in the study",
            "what ratio was used for the analysis",
            "what models are shown in fig 4",
            "what is the conclusion of this study",
            "what do the innovations of this study enable",
            "what is the article about",
            "what is the doi number for the article",
            "where can the tool be accessed",
            "what data has been used",
            "what were the results of the study",
            "what are the key findings of this study",
            "what data sources were used in this study",
            "what are the limitations of this study",
            "where was the research conducted",
            "what are the key words for this article",
            "what is the main objective of this study",
            "what evidence supports the research",
            # Add more phrases here
        ]
        return any(phrase in question.lower() for phrase in count_phrases)
    return False

def is_truncated(sentence):
    
    # Ensure the sentence is converted to a string
    sentence = str(sentence)
    # Define a list of sentence-ending punctuation marks
    sentence_endings = ['.', '!', '?', '."', '!"', '?"', '.”', '!”', '?”']
    
    # Check if the sentence is empty or very short
    if len(sentence) < 2:
        return False  # Not truncated
    
    # Check if the last character of the sentence is a sentence-ending punctuation mark
    if sentence[-1] in sentence_endings:
        return False  # Not truncated
    else:
        print ("\n" + sentence+"\n")
        return True   # Truncated

# Assuming you have defined your functions is_undesirable_question_to_count and is_truncated properly

def count_truncated_questions_and_answers_in_df(df, filtered_data_file):
    #df = pd.read_csv(file_path)
    df.info() 
    columns_with_spaces = df.columns.tolist()
    print(columns_with_spaces) 
    questions = df['Question']
    answers = df['Answer']
        
    questions_count = df['Question'].apply(is_undesirable_question_to_count).sum()

    # Count truncated questions
    truncated_questions_count = df['Question'].apply(is_truncated).sum()

    # Count truncated answers
    truncated_answers_count = df['Answer'].apply(is_truncated).sum()
     
    # Filter out truncated rows
    truncated_questions = []
    truncated_answers = []
    
    # Filter out truncated rows
    not_truncated_indices = []
    for i in range(len(df)):
        if not (is_truncated(questions[i]) or is_truncated(answers[i])):
            not_truncated_indices.append(i)
        else:
            if is_truncated(questions[i]):
                truncated_questions.append(questions[i])
                print(f"Truncated Question {i}: {questions[i]}")
            if is_truncated(answers[i]):
                truncated_answers.append(answers[i])
                print(f"Corresponding Question {i}: {questions[i]}")
                print(f"Truncated Answer  {i}: {answers[i]} \n")
    df = df.iloc[not_truncated_indices]
      
    # Filter out questions and their corresponding answers
    filtered_indices = [i for i, question in enumerate(df['Question']) if is_undesirable_question_to_count(question)]
    filtered_data = pd.DataFrame({
        'Question': df['Question'].iloc[filtered_indices],
        'Answer': df['Answer'].iloc[filtered_indices]
    })
    
    # Print the number of rows in the filtered data
    print("Number of rows in filtered data:", len(filtered_data))
    
    # Create a new DataFrame for remaining data without truncated QnA
    remaining_indices = [i for i in range(len(df)) if i not in filtered_indices]
    remaining_data = df.iloc[remaining_indices]
    
    # Print the number of rows in the remaining data
    print("Number of rows in remaining data:", len(remaining_data))
    
    # Save the filtered data
    filtered_data.to_csv(filtered_data_file, index=False, encoding='utf-8')
    
    # Save the remaining data
    #remaining_data.to_csv(remaining_data_file, index=False, encoding='utf-8')
    
    return questions_count, truncated_questions_count, truncated_answers_count, remaining_data



def save_filtered_data(file_path, filtered_data):
    with open(file_path, 'w', newline='', encoding='utf-8') as csvfile:
        fieldnames = ['Question', 'Answer']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        writer.writerows(filtered_data)

        

def count_errors(text):
    tool = language_tool_python.LanguageTool('en-GB')
    matches = tool.check(text)
    return len(matches)

def LanguageTool_df(df):
    tool = language_tool_python.LanguageTool('en-GB')
    corrected_content = []

    #original_error_count = 0
    #corrected_error_count = 0

    for i in range(len(df)):
        corrected_row = []
        for cell in df.iloc[i]:
            if isinstance(cell, str):
                corrected_cell = tool.correct(cell)
                corrected_cell = corrected_cell.replace(' Answer', 'Answer')
                #original_error_count += count_errors(cell)
                #corrected_error_count += count_errors(corrected_cell)
            else:
                corrected_cell = cell
            corrected_row.append(corrected_cell)
        corrected_content.append(corrected_row)

    LanguageTool_corrected_df = pd.DataFrame(corrected_content, columns=df.columns)

    return LanguageTool_corrected_df #, original_error_count, corrected_error_count

# Assuming you have a function count_errors defined elsewhere in your code

# Example usage:
# corrected_df, original_errors, corrected_errors = LanguageTool_df(your_dataframe)


def validate_and_correct_url_in_dataframe(df):
    def validate_and_correct_url(url):
        if isinstance(url, str):
            try:
                parsed_url = urlparse(url)
                if not parsed_url.scheme:
                    # If the URL doesn't have a scheme (e.g., http://), add "http://"
                    corrected_url = 'http://' + url
                    parsed_url = urlparse(corrected_url)

                if not parsed_url.netloc:
                    # If the URL doesn't have a valid network location, return it as is
                    return url

                # Replace "www" with "www." if it doesn't have a dot after it
                corrected_netloc = re.sub(r'www(?!\.)', 'www.', parsed_url.netloc)

                # Replace "com" with ".com" if it doesn't have a dot before it, and is not followed by a forward slash
                corrected_netloc = re.sub(r'(?<!\.)com(?!/)', '.com', corrected_netloc)
                
                 # Replace "com" with ".org" if it doesn't have a dot before it, and is not followed by a forward slash
                corrected_netloc = re.sub(r'(?<!\.)org(?!/)', '.org', corrected_netloc)
        
        
               # Remove dots from ".com" in the middle of the string
                corrected_netloc = re.sub(r'(?<=\w)\.com(?=\w)', 'com', corrected_netloc)
                
                # Remove dots from ".org" in the middle of the string
                corrected_netloc = re.sub(r'(?<=\w)\.org(?=\w)', 'org', corrected_netloc)
                
                
                 # Replace ".com" at the start of a word with "com"
                corrected_netloc = re.sub(r'\.com(?=\w)', 'com', corrected_netloc)
                
                 # Replace ".com" at the start of a word with "org"
                corrected_netloc = re.sub(r'\.org(?=\w)', 'org', corrected_netloc)
      

                # Reassemble the URL with the corrected netloc
                parsed_url = parsed_url._replace(netloc=corrected_netloc)
                corrected_url = urlunparse(parsed_url)

                return corrected_url

            except ValueError:
                # Invalid URL, return it as is
                return url
        else:
            # If the input is not a string (e.g., it's a float or other non-string type),
            # return it as is
            return url

    if 'Full_Text_URL' in df.columns:
        df['Full_Text_URL'] = df['Full_Text_URL'].apply(validate_and_correct_url)

    return df





def add_space_before_opening_bracket(df):
    #df = pd.read_csv(input_file_path)
    
    for column in df.columns:
        df[column] = df[column].apply(lambda cell: re.sub(r'([A-Za-z])\(', r'\1 (', cell) if isinstance(cell, str) else cell)
    
    #df.to_csv(ammended_space_file, index=False)
    
    return df   # Return the output file path after processing


# Function to correct the truncated starting word of the answers
def correct_truncated_start_word(text: str) -> str:
    if isinstance(text, str):
        # Load the spaCy English model
        nlp = spacy.load("en_core_web_sm")
        doc = nlp(text)

        # Checking if the start token is capitalized or not
        if doc[0].is_title == False:
            first_token = doc[0].text
            if first_token[0].isdigit() and not first_token[-1].isalnum():
                # Correct the word without modifying the '%' symbol
                corrected_word = ''.join([str(TextBlob(part).correct()) if not part.isalnum() else part for part in first_token.split('%')])
                corrected_text = corrected_word + " " + " ".join([token.text for token in doc[1:]])
                return corrected_text.capitalize()
    
        return text
    else:
        return text

def add_full_stops(df):
# function to add full stops to the end of each “Answer” column.
    df['Answer']=df['Answer'].apply(lambda answer: answer.strip()+  '.' if isinstance(answer,str) else answer)
    return df




# Download NLTK data for part-of-speech tagging
nltk.download('punkt')
nltk.download('stopwords')

# POS tagger
tagger = nltk.pos_tag

# Function to check if a word is a noun or other parts of speech
def is_noun_or_other(word):
    tagged = tagger([word])
    pos_tags = ['NN', 'NNS', 'NNP', 'NNPS', 'VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ', 'JJ', 'JJR', 'JJS', 'WP', 'IN']
    return tagged[0][1] in pos_tags

# Function to identify acronyms that are not stopwords and are nouns or other parts of speech
def identify_and_capitalize_acronyms(df, acronyms_df, persons_df):
    # Preprocess acronyms: remove whitespace and lowercase
    acronyms_df['Acronyms'] = acronyms_df['Acronyms'].str.replace(r'\s+', '').str.lower()
    acronyms = set(acronyms_df['Acronyms'])

    # Get the set of English stopwords
    english_stopwords = set(stopwords.words('english'))

    # Preprocess DataFrame
    df['Question'] = df['Question'].str.lower()
    df['Answer'] = df['Answer'].str.lower()

    # Load names of persons into a set
    persons_set = set(persons_df['name'].str.lower())

    for index, row in df.iterrows():
        q_words = re.findall(r'\b\w+\b', row['Question'])
        a_words = re.findall(r'\b\w+\b', row['Answer'])

        q_matches = [word for word in q_words if word in acronyms and word not in english_stopwords and is_noun_or_other(word) and word not in persons_set]
        a_matches = [word for word in a_words if word in acronyms and word not in english_stopwords and is_noun_or_other(word) and word not in persons_set]

        # Capitalize acronyms
        for word in q_matches:
            row['Question'] = row['Question'].replace(word, word.upper())

        for word in a_matches:
            row['Answer'] = row['Answer'].replace(word, word.upper())

         # Capitalize names from persons_df
        for word in q_words:
            if word in persons_set:
                row['Question'] = row['Question'].replace(word, word.title())

        for word in a_words:
            if word in persons_set:
                row['Answer'] = row['Answer'].replace(word, word.title())

    return df

def punc_removal_at_start(input_df):
    try:
        # Create a copy of the input DataFrame to avoid modifying the original
        df = input_df.copy()

        # Define a function to clean a single string by removing non-alphanumeric characters
        def clean_text(text):
            if isinstance(text, str):
                # Find and remove non-alphanumeric characters from the beginning of the text
                cleaned_text = re.sub(r'^[^a-zA-Z0-9\s]+', '', text)
                return cleaned_text
            else:
                return text  # Return non-string values as is

        # Apply the clean_text function to the 'Question' and 'Answer' columns
        df['Question'] = df['Question'].apply(clean_text)
        df['Answer'] = df['Answer'].apply(clean_text)

        return df

    except Exception as e:
        print("An error occurred:", str(e))
        
# Function to format numbers with commas, preserving non-numeric characters
def format_number_with_commas(number_str):
    try:
        # Check if the input is a numeric value
        if isinstance(number_str, (int, float)):
            return locale.format_string("%d", int(number_str), grouping=True)
        
        # Use regular expression to find and format numbers in the string
        formatted_str = re.sub(r'(\d[\d,]*)', lambda x: locale.format_string("%d", int(x.group(0).replace(',', '')), grouping=True), number_str)
        return formatted_str
    except (ValueError, TypeError):
        return number_str

# Function to format numbers in a DataFrame
def format_numbers_in_dataframe(df):
    df_copy = df.copy()  # Create a copy of the DataFrame to avoid modifying the original
    columns_to_format = ['Question', 'Answer']  # Specify the columns to format
    for column in columns_to_format:
        df_copy[column] = df_copy[column].apply(format_number_with_commas)
    
    return df_copy





 
def main():
    # List of CSV files to process
    start_time = time.time() 
    
    
    
    csv_files = [
       # "C:/Users/HP/Documents/Sam/Data Science Voluteer/CSV/Geothermal_energy_wellcome_20230717.csv",
        #"C:/Users/Joshua Giwa/Downloads/QnAs_generated_27_07_2023/Solar power_wellcome_20230717.csv",
        #"C:/Users/Joshua Giwa/Downloads/QnAs_generated_27_07_2023/Solar power_gatesopen_20230717.csv",
        #"C:/Users/Joshua Giwa/Downloads/QnAs_generated_27_07_2023/Geothermal+energy_f1000_20230717.csv",
       # "C:/Users/Joshua Giwa/Downloads/QnAs_generated_27_07_2023/Geothermal_energy_wellcome_20230717.csv",
      #  "C:/Users/Joshua Giwa/Downloads/QnAs_generated_27_07_2023/Carbon+footprint_wellcome_20230717.csv"
      #  "C:/Users/Joshua Giwa/Downloads/test_dataset.csv"
        #"C:/Users/LolaPwasanga/Downloads/datarecords.csv"
       # 'C:/Users/Joshua Giwa/Downloads/8606-subtopics_Clean.csv'
        'C:/Users/Joshua Giwa/Downloads/QnAs_generated_26_07_2023/QnA_Biomass_f1000_20230717.csv'
        ## Add more file paths here as needed
    ]

    total_questions_count = 0
    total_truncated_questions_count = 0
    total_truncated_answers_count = 0
    

    for csv_file in csv_files: 
        df = pd.read_csv(csv_file)
        #print(df.columns)
        
        #df = add_full_stops(df)

        # Removing any punctuation if any from the start of the answer
        df['Answer'] = df['Answer'].str.replace(r'^[\.\:\- ]*', '', regex=True)     # regex to replace the punctuations from the start of the answer

        # Correcting answers that are truncated in the start of the answer
        df['Answer'] = df['Answer'].apply(correct_truncated_start_word)
        
       # Load AcronymsFile_2.csv into a DataFrame
        acronyms_file = 'C:/Users/Joshua Giwa/Downloads/AcronymsFile_2.csv'
        acronyms_df = pd.read_csv(acronyms_file)

        # Load names_of_persons.csv into a DataFrame
        persons_file = 'C:/Users/Joshua Giwa/Downloads/names_of_persons.csv'
        persons_df = pd.read_csv(persons_file)
        
       # result_df = identify_and_capitalize_acronyms(df, acronyms_df, persons_df)
        
        locale.setlocale(locale.LC_ALL, 'en_GB.UTF-8')
        
        formatted_df = format_numbers_in_dataframe(df)
        
        
        #df['Full_Text_URL'] = df['Full_Text_URL'].apply(validate_and_correct_url)

        # corrected_file_path = os.path.join(os.path.expanduser("~"), "Downloads", os.path.basename(csv_file).replace('.csv', '_corrected.csv'))
        #remaining_data_file = os.path.join(os.path.expanduser("~"), "Downloads", os.path.basename(csv_file).replace('.csv', '_remaining_data.csv'))
        filtered_data_file = os.path.join(os.path.expanduser("~"), "Downloads", os.path.basename(csv_file).replace('.csv', '_filtered_questions_non_optimized.csv'))
        #ammended_space_file = os.path.join(os.path.expanduser("~"), "Downloads", os.path.basename(csv_file).replace('.csv', 'bracket_spaced.csv'))
        
        punc_removal_at_start_df = punc_removal_at_start(formatted_df)
        questions_count, truncated_questions, truncated_answers, remaining_data = count_truncated_questions_and_answers_in_df(punc_removal_at_start_df, filtered_data_file)
        comma_cluster_removed_df, total_comma_count = comma_cluster_removal_df(remaining_data)
        space_before_bracket_ammended_df = add_space_before_opening_bracket(comma_cluster_removed_df)
        LanguageTool_corrected_df= LanguageTool_df(space_before_bracket_ammended_df)
        validate_and_correct_url_in_df = validate_and_correct_url_in_dataframe(LanguageTool_corrected_df)  
        
       
        
        # Save the processed DataFrame with "updated" added to the name
        cleaned_df =  validate_and_correct_url_in_df.copy()
        cleaned_df_filename = os.path.basename(csv_file).replace('.csv', '_cleaned.csv')

        # Assuming that you have a directory where you want to save the updated DataFrames
        cleaned_df_dir = os.path.join(os.path.expanduser("~"), "Downloads", "cleaned_QnAs_non_optimized")

        if not os.path.exists(cleaned_df_dir):
            os.makedirs(cleaned_df_dir)

        cleaned_df_file_path = os.path.join(cleaned_df_dir, cleaned_df_filename)

        # Save the updated DataFrame as a CSV file
        cleaned_df.to_csv(cleaned_df_file_path, index=False, encoding='utf-8')


        # Now, you can use the updated DataFrame for further processing if needed

        
        
        total_questions_count += questions_count
        total_truncated_questions_count += truncated_questions
        total_truncated_answers_count += truncated_answers
        
        
        print(f"File: {csv_file}\n")
        print(f"Total undesirable questions: {questions_count}")
        print(f"Total Truncated Questions: {truncated_questions}")
        print(f"Total Truncated Answers: {truncated_answers}")
       # print(f"Original typo/error found: {original_error_count}")
        print(f"excessive comma occurence: {total_comma_count}")
        #print(f"Corrected typo/error count: {corrected_error_count}")

        
        print(f"(undesirable_questions + Truncated Questions + Truncated Answers + excessive comma occurence): {questions_count + truncated_questions + truncated_answers +  total_comma_count}\n")

  #  print(f"Total Questions Count: {total_questions_count}")
  #  print(f"Total Truncated Questions Count: {total_truncated_questions_count}")
  #  print(f"Total Truncated Answers Count: {total_truncated_answers_count}")
  #  print(f"Total (Questions + Truncated Questions + Truncated Answers): {total_questions_count + total_truncated_questions_count + total_truncated_answers_count}")

    end_time = time.time()
    
    elapsed_time_seconds = end_time - start_time
    elapsed_time_minutes = elapsed_time_seconds / 60

    print(f"Script ran for {elapsed_time_minutes:.2f} minutes.")
    
    
    
    
if __name__ == "__main__":    
    main()
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Joshua
# [nltk_data]     Giwa\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Joshua
# [nltk_data]     Giwa\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10219 entries, 0 to 10218
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Title          10219 non-null  object
#  1   DOI            10219 non-null  object
#  2   Authors        10219 non-null  object
#  3   Full_Text_URL  10219 non-null  object
#  4   Paragraph      10219 non-null  object
#  5   Question       10213 non-null  object
#  6   Answer         10177 non-null  object
# dtypes: object(7)
# memory usage: 559.0+ KB
# ['Title', 'DOI', 'Authors', 'Full_Text_URL', 'Paragraph', 'Question', 'Answer']
#
# How did the Pn of white birch respond to high temperature conditions and elevated CO
#
#
# A):
#
#
# A):
#
#
# What parts of Europe have been studied in regards to the temporal dynamics of populations of
#
#
# How does hydroxymethyl affect the N
#
#
# How did we determine hydrogen peroxide (H
#
#
# What is the purpose of the Mans
#
#
# What was found in the elemental analysis from the surface of Ag coated Ti from 0.1 mol/L AgNO
#
#
# What is the proof of
#
#
# How can we prove that
#
#
# What is the relationship between water content and H
#
#
# How is the linear regression of H
#
#
# nan
#
#
# nan
#
#
# What is the function that can be used to import data to M
#
#
# What is the function that can be used to segment data in M
#
#
# How much were the mean daily wind speeds
#
#
# What is the assumption related to the selection of m and t
#
#
# What procedure was used to detect changes in APOE expression levels during in
#
#
# How did the leaf photosynthetic rate, stomatal
#
#
# What is depicted in figure 2
#
#
# nan
#
#
# What factors affect enzyme activity according to Yamin and Palinggi
#
#
# What is the IC
#
#
# How did the treatment of
#
#
# What was the yield of the A. subulata etan
#
#
# What
#
#
# What does the RMSD representation of the thioesterase motif (H241 S114 V136 W213) compared to a trypsin protein (PDB:
#
#
# How are the proteins
#
#
# How were the
#
#
# nan
#
#
# nan
#
#
# What types of well-being
#
#
# What phenotypes were observed in the F1s from a cross between APC11/apc11-2 and TAM-GFP/T
#
#
# What effects did the ethanol extract of
#
#
# What other cells was the chloroform:methanol (1:1) leaf and stem extracts of
#
#
# What is the best way to search for
#
#
# What are the molecular mechanisms of Estrogen Receptor (ER
#
#
# nan
#
#
# How was the deacetylation of nuclear
#
#
# What does the baseline population of N never smokers subdivided in a 2 × 2 table according to presence or absence
#
#
# What characteristics indicated the isolation of
#
#
# How does the model respond to a constant increase/decrease to measured P
#
#
# What is Optical Coherence Tomography (OCT)
#
#
# What type of plot was generated to measure
#
#
# What is the primary clinical goal
#
#
# The in vivo maximal carboxylation rate (Vcmax), PAR-saturated electron transport rate (Jmax), triose phosphate utilization (TPU) and other relevant parameters were calculated from the Pn-Ci curve according to Farquhar et al., van Caemmerer and Farquhar, Sharkey, Harley and Sharkey and Harley et al. The Pn-Ci curves were fit using the Photosyn Assistant software (Dundee Scientific, Scotland, UK) to estimate V
#
#
# There was a significant (P<0.1) interactive effect of CO2 and temperature on (Fm’-F)/Fm’ and JT. Temperature greatly increased (Fm’-F)/Fm’ and JT at 37°C as compared to at 26°C under elevated CO2 and there was no significant temperature effect on (Fm’-F)/Fm’ and JT under ambient CO2. The pattern of CO2 and temperature effects on Jc was almost the same as (Fm’-F)/Fm’ and JT, and Jc was greater (P<0.1) at 37°C than that at 26°C under elevated
#
#
# caryochloris was provided near infrared radiation (NIR) by narrow band LEDs (L720-4AU, 700–740 nm, centered at 720 nm, Epitex Inc., Japan) at an irradiance of 20–40 µ
#
#
# nan
#
#
# The findings from the study showed that outbreaks sometimes occurred contemporaneously along the Scandes and sometimes moved as a wave from north to south along the Scandes or from south to north. However, it was later found that these patterns were illusions caused by continental-scale outbreak waves passing the Scandes either in parallel or obliquely from north or south. Another study showed that during the four outbreak periods from 1,970-2,004
#
#
# The tree species examined in the study in terms of their location were Platycarya longipes, Lithocarpus glabra, Celtis sinensis, Ligustrum lucidum, Quercus aliena var. acutiserrata, Lindera communis, Daphniphyllum oldhami, Stachyurus obovatus, Carpinus pubescens, Itea chinensis, Zanthoxylum ovalifolium var. spin
#
#
# Photosynthetic rate (Pn), stomatal conductance (g
#
#
# cetone at room temperature was used for fixation of the tissue sections
#
#
# CM-Medium
#
#
#  The Gfp-Cl1 overexpression plasmid was generated by 3 fragment ligation. The Gpd promotor from Aspergillus nidulans, the eGfp gene, and the first part of the Cl1-sequence were amplified by PCR with the plasmid pSM5 as template and with primers eGfp-Pgpd-cl1for (CCTCGAGG
#
#
# The binding of CO on the optical spectra of H81V and H81Y Cygbs leads to a hypsochromic shift of the Soret with an increase in intensity and an appearance of
#
#
# The distal histidine mutants exhibit different EPR spectra to the WT monomer. The H81V mutant has a much greater HS signal, indicating it is primarily pentacoordinate in the ferric state. For the H81Y variant, there is a notable contribution from the rh
#
#
# The second order rate constant of myoglobin reacting with hydrogen per
#
#
# The presence of a hydroxymethyl slightly weakens the N
#
#
# Similar observations were made from analogous treatment of methylated ACA (data not shown), indicating that DFT, QM/MM and MM methods can all produce almost equally adequate DNA structures, but that QM/MM and MM approaches are more similar to
#
#
# Table 1 provides the details of the templates, BLAST results, MODELLAR results, ProSA results, and Ramachandran plot analysis used to generate the best-ranked models for the structural and nonstructural proteins of CHIKV. It also includes specific validation information such as PDB IDs, max score, total score, e-value, identity
#
#
# Research conducted using photocatalytic technology includes studies by N. Chen et al. on the reactive oxygen species generation in hydrochar and photochemistry of Sulfadimidine degradation in water, Y. Chen et al. on the photo degradation of tetracycline in aqueous solution under simulated sunlight irradiation, and Li et al. on the removal of herbicide bispyribac sodium
#
#
# The degradation of ibuprofen by UV–visible light irradiation involves direct photolysis and self-sensitization via ROS. In simpler molecules which lack visible-light absorption, the Fe-hydroxyl complexes still promote the generation of ROS and thus accelerate degradation, although the exact pathway of electron transfer and the mechanism of photocatalysis are not yet
#
#
# The mechanisms that can result in the generation of reactive oxygen species (ROS) in this nanocomposite material include the transfer of
#
#
# alysis of the ion intensity of MS spectra of DFTP+31.990VCTTELGR and its non-conversion counterpart DFTPVCTTELGR peptide determined that the mass shift of + 31.990 Da on proline 45 occurs in 5–10% of the Prx6 molecule
#
#
# We found that when human cells were treated with H
#
#
# Treatment of cells with H2O2 caused the shift of the 55 kDa band to 40 kDa, suggesting that one of the two cysteines got oxidized by H2O2. In rat cells where Prx6 has only the catalytic cysteine, H2O2 caused the shift of the
#
#
# nan
#
#
#  (826,000) adults and 73% (71,500) children in Kenya were estimated to be receiving antiretroviral therapy in 2,018.
#  - The first-line antiretroviral therapy guidelines for children, youth and adults in Kenya typically contain two nucleoside reverse transcriptase inhibitors (NRTIs; zidovudine [AZT], stavudine [d4T], tenofovir [TDF] or lamivudine [3TC]), plus one non-nucleoside reverse transcriptase inhibitor (NNRTI): either nevirapine (NVP) or efavirenz (
#
#
# The NVP plasma concentrations were measured using a Xevo TQ-S tandem quadrupole mass spectrom
#
#
# The sample was quantified by injecting approximately 1μl of the samples
#
#
# For the HIV gen
#
#
# In this study, CYP2B6 516G>T and 983T>C SNPs were correlated with increased mean NVP plasma concentrations. Patients who had the homozygous mutation of CYP2B6 516G>T (CYP2B6 516TT) had higher median NVP plasma levels than those with the wild-type genotype (CYP2B6 516GG). In the case of CYP2B6 983T>C, the median NVP plasma concentrations were higher among patients who had the heterozygous genotype (CYP2B6 983TC) than those who had homozygous wild-type (CYP2B6 983TT), but the distribution was not
#
#
# Carriers of the CYP2B6 c.516 T allele have been found to have a genotype dose-dependent increase in NVP plasma concentration. Furthermore, individuals with the heterozygous mutant genotype (CYP2B6 983TC) have been found to have
#
#
# The presence of a specific mitochondrial genetic code in ascidians has been confirmed by the observation of the cytochrome c oxidase subunit 1 (Cox1) sequence from Halocynthia roretzi and the Cox3 sequence of Pyura stolonifera being interrupted by stop codons when translated using the vertebrate mitochondrial code; in addition, the discovery of a glycine (Gly) tRNA in the H. roretzi genome and the sequencing of its
#
#
# The Cox1 accession numbers for the seven organisms referenced in the paragraph are Bathochordaeus charon (KT881,544.1 ORF2 translated with asc
#
#
# nan
#
#
# The average affinity energy, ZINC identification, and the chemical classifications of the 40 best molecule hits are -8.86 (Kcal/Mol), peptide-like, β-carboline Alkaloid, harmala alkaloids, polyflavonoids, anthracenes, angular pyranocoumarins
#
#
# Polar interactions, π-π stacked, π-sulfur, van der Waals, hydrogen, oxygen, halogen-bond and hydrophobic interactions were all observed
#
#
# Ligand ZINC3,984,030 (Figure 5C) interacts with THR26 TYR54 and GLU166 residues and forms three hydrogen bonds by OH groups of flavonoid nuclei. It also forms three polar interactions (π-π stacked, π-alkyl and π-sulfur) with HIS41 CYS145 and MET
#
#
# The re-docking validation experiments yielded favorable results, as both N3 and OEW molecules bound into similar positions in comparison to their original crystallographic forms. The best clustering conformations for N3 had a free energy of binding ranging from -1.83 kcal/Mol to -9.7 kcal/Mol and presented an
#
#
# The anthocyanin was extracted by macerating 200 g
#
#
# The mechanisms of interaction associated with these miRNAs are duplex and triplex formation with enh
#
#
# Intesti-bakteriofag” is a commercial therapeutical bacteriophage preparation that is active against Shigella flexneri, S. sonnei, S. paratyphi A, S. paratyphi B, Salmonella typhimurium, S. infantis, S. choleraesuis, S. oranienburg, S. enter
#
#
# The elemental analysis from the surface of Ag coated Ti from 0.1 mol/L AgNO
#
#
# Figure 4 shows a scanning electron microscope image (A) and energy dispersive X-ray analysis element mapping images of Ag coated Ti from 0.1 mol/L AgNO
#
#
# The cryo-mixture used to cryoprotect the crystals consisted of the crystallization buffer and Cryomix 9 from CryoSol MD1-90 (Molecular Dimensions) containing 0.2 M NaI, 0.1 M Bis-Tris propane pH 7.5 5 % (w/v) PEG 3,350 10% (v/v) EG 5%, (v/v) diethylene glycol, 5
#
#
# The total phenol content was measured using modified Folin-Ciocalteu methods. Samples were sonicated for 30 minutes prior to measurement, and the absorbance of the sample was recorded. The total phenolic content of the sample was expressed as milligram gallic acid equivalent/gram sample (mg GAE/
#
#
# O. basilicum intervention can increase the levels of phycocyin in S. platensis 40.72%, and the bioactive compounds such as total phenol, flavonoid, and antioxidant activity for 117.24 ± 8.6 mg GAE/g, 7.4 ± 0.18 mg QE/g and 94.93 ± 2.24%, respectively
#
#
# The volatile compounds that contribute to the off-odour of S. platensis are geosmin, 2-Methylisoborneol and medium chain-alkanes.
# swer 3: The combination of polyanion and polycation coatings with a higher yield is maltodextrin
#
#
# The physicochemical parameters of the analysis compounds all meet the criteria set by the Rule of 5; the molecular weights of phenol, azulene, and phycocyanin are all under 500 g mol-1 the acceptor hydrogen bonds are all
#
#
# The DLP median for the 100 kVp protocol for a matrix size of 1,024 is 372.75 (Q1=355.52 Q3=387.92), while the DLP median for the 100 kVp protocol for a matrix size of 512 is 352.2
#
#
# The mice were divided into six groups with each group consisting of six mice. Group N (obese mice control), O1 (obese mice induced of 2-Nitropropane 20 mg/kgBW intraperitoneal (i.p.) once), O2 (obese mice induced of 2-Nitropropane 20mg/kgBW i.p. twice), P1 (obese mice induced of 2-Nitropropane 20 mg/kgBW i.p. once and gavage with
#
#
# Liver homogenate samples were prepared by putting 100 mg of rat liver tissue into a 1.5 ml Eppendorf tube, adding 1 ml of phosphate buffered saline (PBS) (0.1 M pH 7.4), crushing using a homogenizer for 90 seconds at a speed of 3,500 rpm, centrifuging for 10 minutes at 3,500 rpm, transferring the supernatant to a new Eppendorf tube, and placing the tube in the refrigerator with
#
#
# The counter example is the set of matrices A = [1 2; 3 6] and B = [2 2; 1 1], together with outer inverses GA = [1 0; 0 0] and GB = [0 1; 0 0
#
#
# The equivalent condition for the inclusion {B{12}A{12}} ⊆ {(AB){12}} is given in 28 for bounded linear
#
#
# The proof of
#
#
# We can prove that
#
#
# The consequent physiological, biochemical, and molecular changes caused by drought stress affect various cellular processes, thereby reducing the quantity and quality of the plant yield.
# swer 3: The objective of this study is to determine the mechanism of drought-tolerant
#
#
# The lowest H2O2 level
#
#
# The lower the water content, the higher the concentration of H
#
#
# The linear regression pattern between H
#
#
# The EOs selected for further testing against B. Subtilis were C. cassia, C. sinensis, C. martinii var. motia, E. cardamomum, E. caryophyllus, M. x piperita, T. vulgaris CT LINALOL and T. satureioides. This selection was
#
#
# The difference in muscles used during the two movements (Ruku’ and Sajdah) might be the cause for the distinct finding. Ruku’ uses neck extensors (NE), deltoid (DT), triceps brachii (TB), and rectus abdominal (RA) muscles; while Sajdah uses sternocleidomastoideus (SCM), trapezius (TRP), biceps brachii (BB), and erector spinae (
#
#
# The content of flavonoids in green tea is influenced by weather, climate, tea varieties, geographical location, soil conditions, leaf age, and the way of picking.
# swer 3: EGCG in green tea is 100 times more effective in eliminating free radicals than vitamin C and 25 times more effective than vitamin E.
# swer 4: The results of the study showed that the longest
#
#
# Impact Refinement (Impref) module is a module of the Schrödinger suite 2,017-1 used for restrained molecular minimization with heavy
#
#
# The nomenclature
#
#
# ll calculations were carried out using the method B3LYP
#
#
# Clusterid 32 in Table 2 of Figure 2 Core genes of the V. cholerae SI has a conservation level of 7 and a COG* of COG1,694R. The description is mazG-related protein with the corresponding
#
#
# The digestibility results indicated that the three Moringa oleifera samples had higher digestible calcium than spinach and sweet potato leaves. Using Tukey’s Studentized Range Test at α=0.5 there was no significant difference in total digestible calcium between the two samples from Malawi, M4
#
#
# Oocytes expressing Cqui\Orco were exposed to 60 sec applications of 30µM
#
#
# ltering the concentration of Orco agonist (OLC12) shifts the tryptamine inhibition curve. The IC50 for tryptamine inhibition of Cqui\Orco activation by 30µM OLC12 (4.7 ± 0.7µM, n = 5) is significantly different (p<0.1 F-test) from the IC50 for tryptamine inhibition of Cqui\
#
#
# The equation used to fit the concentration-inhibition data is I = Imax/(1+ (X/IC50)n), where I is the current response at a given concentration of inhibitor
#
#
#  0.7µM
#
#
# They tested the ability of tryptamine to inhibit odorant activation of ORs formed by Agam\Orco and each of six different odorant-binding subunits chosen from across the An. gambiae OR gene family. In addition to Agam\Orco+Agam\Or65 (activated by eugenol), they tested Agam\Orco+Agam\Or27 (activated by L-fenchone), Agam\Orco+Agam\Or28 (activated acetophenone), Agam\Orco+Agam\Or31 (activated by geranyl acetate), Agam\Orco+Agam\Or39 (activated by 6-methyl-5-hepten-2-one) and Agam\Orco+Agam\Or48 (activated by 2-nonanone
#
#
# nan
#
#
# nan
#
#
# nan
#
#
# nan
#
#
# The xlsread function can be used to import data to M
#
#
# The ginput function can be used to segment data in M
#
#
# The value of aV is estimated by applying the sin, cos and arcsin functions, along with the interim values in the vertical direction, a′ν, derived from the anterior-posterior plane, aA. The formula used is aV = a m sin θ m + a ′ ν cos
#
#
# The PCR samples were purified by mixing 52.5 μL of Agencourt Ampure XP
#
#
# The potentially pathogenic bacterial species detected at proportions of >1% of classified bacterial reads on plant material before growth include: Acinetobacter baumannii, Acinetobacter pitti, Corynebacterium diphtheriae, Coxiella burnetii, Escherichia coli, Propionibacterium acnes, Pseudomonas aeruginosa, Ralstonia pick
#
#
# The correlation between CFU per gram of plant material and Cq is 0.99 across the remaining eight
#
#
# We observed that there is a tRNA gene (tdbD658-GluCTC), which aligns perfectly to the rat genome, and which is still absent in the latest version of the UCSC database. Additionally, we detected tRFs from all nine sequencing libraries mapping to tdbD658-GluCTC sequence. These observations suggest that there are potentially other tRNA genes lacking annotation in
#
#
# Electron microscopy clarified that the fine blue granules present in the cytoplasm
#
#
# Two dimensional gel electrophoresis (2DE) was performed according to standard 2DE techniques. Briefly, 50 µg of protein was applied to vertical rod gels (9M urea, 4 % acrylamide, 0.3 % PDA, 5 % glycerol, 0.6% TEMED and
#
#
# Peptides are separated on a Zorbax 300 SB C18 column (75µmx150mm; Agilent) using an acetonitrile/0.1% formic acid gradient from 5 to 35% acetonitril within 40 minutes.
# swer 3: The fluoren-9-ylmethoxycarbonyl strategy is used throughout the peptide chain assembly
#
#
# The six specific Plasmodium falciparum antigens coupled to different bead populations to create a multiplex panel were circumsporozoite surface protein (full length CSP, purchased from Sanaria), NANP repeat region of CSP and C-term part of CSP (obtained from Walter Reed Army Institute of Research - WRAIR, USA), MSP2 (from 3D7 strain, obtained from the Institute of Immunology & Infection Research and Centre for Immunity, Infection & Evolution, University of Edinburgh, UK), MSP3 (from 3D7 strain, obtained from the International Centre for Genetic Engineering and Biotechnology, India), EXP1 (purchased from Sanaria), and hepatitis B surface antigen (HBsAg, purchased from Abcam
#
#
# The size and position of the image in the visual field used as a reference to calculate the number of neurons activated by the visual stimulus is 1×1 to 2×2 deg
#
#
# The volume and number of neurons activated by the same visual stimulus can be computed from cell magnification factors derived by Malpeli et al. (1,996) for parvocellular and magnocellular layers, through the equations: Np = 1,011,688(2.9,144 + E)–2.6,798 and Nm = 2,620.2(5.5,638 + (E - 1.8,322)2)–0.8
#
#
# Lin et al. (2,013) observed a group of miRs (such as miR-23a
#
#
# nan
#
#
# The inoculated cells were harvested at 20 hpi and prepared according to Tokuyasu (1,973; 1,980). Cells were fixed with 4% formaldehyde in 0.1 M Na-phosphate, pH 7.4 for 2 h at room temperature, scraped from the flasks, washed three times with 0.1 M Na-phosphate, pelleted in 12% gelatine by centrifugation, gelated at 4°C, infiltrated blocks were mounted on specimen holders, frozen by plunging into liquid nitrogen, and placed into the cryo-microtome (UC
#
#
# The patient underwent incomplete surgical resection due to tumor adherence to the brachiocephalic venous trunk. The patient was referred for adjuvant radiotherapy and received 54Gy (1.8Gy/fraction) over the tumor bed and a total of 60 Gy (2Gy/fraction) in 30 fractions over residual tumor, by tomotherapy
#
#
# gative sample will form two visible lines on the nitrocellulose membrane, one where the free detection antibody binds to the FB1-BSA conjugate immobilized
#
#
# Total phenolic content from dried samples of 100 gr was analysed using the method of Folin-Ciocalteu from Musa et al. 31. Gallic acid solution was initially dissolved into five concentrations (20 40 60 80 and 100µg/ml) for the standard curve. About 100 μl of hydrolysis and
#
#
#  The total phenolic content is represented in milligrams (mg) of gallic acid per gram of the dry weight of mango leaves (mg GAE/g). The total flavonoid content is represented in milligrams (mg) of quercetin per gram of the dry weight
#
#
# The other phenolic and flavonoid compounds present in mango are mangiferin, protocatechic acid, catechin, alanine, glycine, γ-amino-butyric acid, kinic acid, shikimic acid, and the tetra cyclic triterpenoids cycloart-24-en-3p,26-diol,3-keto dammar-24(
#
#
# 50 (70%)
#
#
# 50 (36%)
#
#
# nan
#
#
# The main factors affecting the prediction results are the values of V
#
#
# The assumption related to the selection of m and t
#
#
# Neural passaging 1 2 and 3 were performed with Accutase (Thermo Fisher) on D7 D12 and D15/16 respectively. Briefly, cells were washed with room temperature HBSS and treated with Accutase at 37°C, 5% CO2 5% O2 for 3–4 minutes. Cold Accutase was used for neural passagings 1 and 2 and room temperature Accutase was used for neural passaging 3. Cells in Accutase were then collected with a P1,000 pipette. Extra care was taken during neural passagings 1 and 2 where P
#
#
# nan
#
#
# nan
#
#
# nan
#
#
# This project includes raw data for qPCR.csv (C(t) values, efficiency of amplification, and values calculated for normalised gene expression analysis for APOE), Lee et al. raw data for Genotyping.TIF (Gel image used in Figure 1. Genomic DNA from human iPSCs amplified for the APOE locus, then digested with HhaI enzyme. Run on 3% agarose gel), Lee et al. raw data for DS D12 Hoechst.tif, Lee et al. raw data for DS D12 SOX2.tif, Lee et al. raw data for DS D12 APOE.tif, Lee et al. raw
#
#
# Researchers estimated the overall prevalence in Switzerland by averaging the relative frequency or proportion of the BMI categories across five data sets and calculating 95% confidence intervals via standard deviations. They also used official population numbers for adults in the corresponding survey years
#
#
# Evidence from large samples of patients in Paris, the UK, and New York suggests
#
#
# The importance of biodegradability in scaffolds is that the scaffold must be absorbed by surrounding tissues, without repeating the surgery process. The time needed by the scaffold to be degraded must be the same with tissue development period.
# swer 3: The addition of EDC to the scaffold can be proven by observing a lower degradation compared to that of an untreated scaffold. For example, a scaffold with EDC has
#
#
# Knowing the prevalence of back pain and postural changes in basketball players is
#
#
# The study is currently at the stage of study selection and data extraction.
# swer 3: It is expected that this systematic review can support the implementation of programs and actions for preventing the injuries caused by postural changes and back pain, improving health, quality of life, and sports performance.
# swer 4: Potential limitations of this systematic review include varying levels of musculoskeletal disorders and outcomes due to various measurements and tools, a lack of clarity in the definition of musculoskeletal disorders which may complicate the comparisons, and
#
#
# No, perineurial thickness was not quantified in
#
#
# nan
#
#
# nan
#
#
# Relative water content was calculated using the Weatherly methodology, leaf chlorophyll content was measured with a soil plant analysis development (SPAD) meter 502 plus, the Fv/Fm ratio was calculated using the Mini PAM II fluorometer (MINI PAM II- Walz, Effeltrich, Germany), leaf photosynthetic rate and stomatal conductance were measured with a portable photosynthesis system (
#
#
# nan
#
#
# The peroxidase (POD) activity was determined by the procedure described by Hemenda and Klein, and the reaction mixture contained 25 mmol L-1 phosphate buffer saline (pH 7.0), 0.5% guaiacol, 10 mmol L-1 H2O2 and enzyme. The peroxidase activity was
#
#
# nan
#
#
# The labels featured on the Figure 2 are: BI: basal in folding; BM: Bruch's membrane; CC: choriocapillaris; CP: cytoplasmic processes; DBI: descending basal infolding; DBM: disintegrated Bruch's membrane; GB: Golgi bodies; L: lysosomes; M: mitochondria; N: nucleus; OS: outer segments; Ph: phagosomes; RER: rough endoplasmic reticulum
#
#
# The ultrastructural investigation of the RPE in control and PJ groups of mother rats revealed a single layer of low cuboidal cells with numerous basal (scleral) infoldings and apical (vitreal) processes enclosing the tips of outer segments of photorecept
#
#
# The outer nuclear layer of Pb-treated mother rats and their neonates appeared with multiple pyknotic nuclei and fragmented cell membranes with wide intercellular spaces. Both cytoplasm and nuclei of RPE cells were also completely filled with many vacuoles (
#
#
# The bipolar cells are numerous, rounded or oval in shape and each is prolonged into an inner and an outer process. The horizontal cells are branched and larger than the bipolar cells. The amacrine cells are characterized by a number of ramifications, while the Muller cells display a highly br
#
#
# The time of observation in this study was carried out on the 3rd day and the 6th day after skin excision.
# swer: Another study on the back skin of rats that were injured using a 6 mm diameter punch biopsy without using a wound dressing showed that the number of neutrophils after a skin wound increased within 12 hours and reached a maximum value on the 2nd day, tending to level off until the 3rd day
#
#
# The mechanism responsible for the inhibition of COX-2 expression in the treatment group is that fibroin and sericin contained in the silkworm cocoons have the ability to inhibit the activation of NFkB, thereby inhibiting the synthesis of IL-1 and TnFα. This causes reduced stimulation of cell membrane phospholipids, leading to reduced COX-2 protein synthesis and reduced prostagland
#
#
# The silkworm cocoons were dried with silica gel desiccant for 24 hours.
# swer: The wound dressing was sterilized using a sterilization pack and ethylene oxide gas (EOG) at 36°C for 7 hours.
# swer: The JPG file showing the wound excision is showing the wound excision on the skin of the rat's back with a punch biopsy and closed with a silkworm coc
#
#
# nan
#
#
# The gonadal maturity stages (GMS) II, III, and IV of the female broodstock are as follows: GMS II, the ovary containing the egg is dark green and visible to the naked eye; GMS III, the ovaries fill approximately 70% of
#
#
# Newly hatched M. padangensis larvae were observed to swim vertically to the surface of the water and then return to the bottom of the container. Then, larvae settled at the bottom of the
#
#
# nan
#
#
# The two main types of erythropoiesis are typically distinguished by the presence of large nucle
#
#
# The GFP-specific rabbit polyclonal IgG (ab290) was from Abcam; CIB1-specific rabbit polyclonal IgG (11,823-1-AP) was from ProteinTech Group, Inc.; CD34-specific rat monoclonal IgG 2a (sc-18,917) and non-reactive goat polyclonal IgG (sc
#
#
# The peak activity level during single conditions was 6.67×10-4 ΔF/F, while coherent conditions led to an activity level of 7.86×10-4 ΔF/F, which corresponds to an increase of 18%. This difference in activity level is attributed to the impact of long-range interactions on cortical
#
#
# Endobronchial intubation
#
#
# nan
#
#
# Figure 5b (logP values were calculated as a measure of lipophilic character) shows that the majority of compounds in both the high- and low-confidence data sets had lipophilicity values
#
#
# The quality indicators were computed by comparing the original read intensity profile with those observed in a fraction of the total mapped reads. Total mapped reads (TMRs) were randomly sub-sampled at three defined subsets (90%, 70% and 50% respectively), and the read counts in 500 nt bins of the genome were computed for each of the random sub-sampled as well as in the original dataset. Quality indicators were then computed as the difference between the original and the subsets in terms
#
#
# The process for immunoprecipitated chromatin recovery involves magnetic bead separation followed by a 4-step washing process using 0.1% SDS, 1% Triton X-100 2mM EDTA, 20mM TrisHCl pH 8 150mM NaCl, 0.1% SDS, 1% Triton X-100 2mM EDTA, 20mM TrisHCl pH 8 500mM NaCl, 0.25M LiCl, 1% IGE
#
#
# B): The boxplot of umb
#
#
# The wash-in time for 1.5 MAC concentration at a fresh gas flow of 0.5 L/min for the Flow-
#
#
# Factors such as fresh gas flow, circle system volume, and the use of different agents may contribute to
#
#
# The suggested approach to achieving the desired increase in current grain yield levels has the advantage of requiring reduced levels of fertilizer
#
#
# user can search the NtUE web resource by entering a keyword (e.g. N, P, K, Zn, Fe), organism name (e.g. Arabidopsis thaliana, Brachypodium distachyon, Oryza sativa, Triticum aestivum, Hordeum vulgare), gene name (NRT1
#
#
# CTRS is calculated as the sum of a variant's weighted individual clinical assertions (i). This calculation includes factors such as B = -6 LB = -3 US = -0.3 LP = 3 and P = 6 with
#
#
# The age of the assertion factor reduces the assertion weight over time after a buffer. For the first 2 years, there is no penalty, then there is a 10% reduction gradation in weight per year through 6 years, at which point the penalty
#
#
# If a rejection rate greater than 0 is specified, trial-wise thresholding is applied according to:
#
#
# The intact mandibular 1st molar teeth with three roots were collected from patients (age range 40–50 years
#
#
# Industrial Razor Blades, Forceps, Small Scissors, Hanks' Balanced Salt Solution, 0.25% Trypsin/EDTA, MgSO4 DNase I, BSA, 10% FBS, Penstrep, Soybean Trypsin Inhibitor, B27 Supplement, EGF Recombinant Human Epidermal Growth Factor, 18-gauge Needle,
#
#
# Using one-way ANOVA, we found a significant difference in the number of neurospheres per field of view between the replicates (F (4,129) = 11.666; p < 0.1). Post hoc analysis using Bonferroni's multiple comparison revealed a significant difference between neurospheres with sizes greater than 100
#
#
# The interactions between the SARS-Cov-2 Spike protein and hACE2 that facilitate binding include Lys417 (Spike) --Asp30 (hACE2), Tyr453 (Spike) --His34 (hACE2), Gln474 (Spike) --Gln24 (hACE2), P
#
#
# The multiplex PCR involved mixing 2.5 µl 10X PCR buffer, 0.5 µl dNTPs, 0.125 µl Taq DNA polymerase, 0.1 µl of each specific primer to 10 pmole, 2 µl DNA template and 18.657 µl DNAse/RNAse-free distilled water in a 25 µl reaction mix. The DNA was then amplified using a program of initial heating at 94°C for 5 min followed by 30 cycles of denaturation
#
#
# Examples of the items include “My job allows me to be creative in performing my responsibilities”, “My organization encourages me to use my skills and capabilities in the work process”, “I often think of ways and suggestions to improve my work”, “I feel a sense of belonging and identify with my organization”, I am proud to work in this organization”, “I feel like staying in this organization”, “I exert a lot
#
#
# Figure 1 depicts the PLS algorithm model of workplace management initiatives and talent engagement. PLS stands for Partial Least Squares and PLS Algorithm
#
#
#  The pooled analysis of OR of 10 individual studies showed that patients with obesity had overall RR to the risk of nephrolithiasis of 1.531
#
#
# The vitamin mix contains thiamin, riboflavin, Ca-pantothenate, niacin, pyridoxin, biotin, folic acid, cyanocobalamin, inositol, ρ-aminobenzoic acid, men
#
#
# Protease activity was determined using the method used by Bergmeyer et al. 15. 0.1 M borate buffer (pH 8) was added into 2% casein substrates. The mixture was incubated at 37
#
#
# No, there was no statistically significant difference in recruitment between the use of a wet-ink signature versus a generic signature
#
#
# The project includes images of the zone of inhibition of BS2
#
#
# nan
#
#
# nan
#
#
# MGISEQ is compatible with a wide range of reagents for sequencing in SE50 SE100 SE400 PE100 PE150 and PE200 modes.
# swer 3: Yes, the MGISEQ-2,000 provides the quality of sequencing comparable with that of the Illumina platform.
# swer 4: According to our experience, one PE150 run usually
#
#
# nan
#
#
# NR
#
#
# Two 12 mm and two 5 mm port
#
#
# The pooled analysis showed that the SILC procedure did not differ from the CMLC procedure in terms of risk for bile leakage incidence [RR
#
#
# The SILC procedure did not differ from the CMLC procedure in terms of conversion to open
#
#
# common adducts (M+H-2H2O, M+H-HO, M+NH4 M+Li, M+NH4 M+CH3OH-H, and M+K) and 27 common predicted biotransformations (M+CH3 M+C6H12O6 M+OH, M+COOH, M+NH2 M+NH3 M-H+OH, M-H+2OH, M-H+NH2 MCH3+H, M-CH3+OH, M-CH3+NH2 M-C6H12O
#
#
# The elution is used with the Waters Acquity UPLC BEH C18 column (2.1 × 150 mm × 1.7 μm) at a temperature of 30 °C and consists of 0.25% formic acid (Sigma) in ultrapure water (Eluent A) and 100% acetonitrile (Eluent B). It is performed using a gradient of 0.0-10.0 min, 95:5-5:95 v/v, 10.0-15.0 min, 5:95 v/v, 15.0-20.0min, 5:95-95:5 v/v
#
#
# mixture of 46 known analytes were weighed then dissolved in the 0.5 N trichloroacetic acid and 80% methanol extraction buffer and then injected to determine
#
#
# The in silico RT prediction was performed using the Retip package in the R environment, which used the in-
#
#
# The 14 datasets archived on the Metabolomics Workbench explored in the meta-analysis of plant
#
#
# The Synthetic Biotransformation approach has been found to be highly accurate in metabolomics data analysis, with the spectral libraries
#
#
# The IC
#
#
# The treatment of
#
#
# nan
#
#
# The cell lines used in the experiment were purchased from the American Type Culture Collection (
#
#
# It is important to evaluate proteins such as p53
#
#
# Day bruxism and night bruxism were proposed to have different definitions at a meeting of different specialties in 2,020. Day bruxism is indicated as awake bruxism and night bruxism is indicated as sleep bruxism.
# swer 3: The main methods used for treatment of bruxism are increasing the vertical dimension of occlusion (VDO) to normal, mesialization of the jaw to influence the position of the articular condyle in the articular fossa and releasing the disc, and positioning the jaw
#
#
# The keywords used to search for relevant studies included smartphones apps, awake bruxism, sleep bruxism, sleep hygiene, parasomnias, habits, chewing, teeth grinding, squeezing teeth, parafunctional habits, parafunctional habit, oral habits, oral parafunctional, parafunctional oral habit, facial pain, temporomandibular joint disorders, temporomandibular joint dysfunction syndrome, myofascial pain, syndromes, myalgia, osteoarthritis, pandemic cov-19 orofacial pain, tmd, stress, temporomandibular disorder, myofas
#
#
# Bram
#
#
# The study by Reissmann et al. (2,017) used a 705 patient sample over an 7 day period to explore the association between awake bruxism (OR = 6.7; 95% CI 3.4 to 12.9) and sleep bruxism (OR = 5.1; 95% CI 3.1 to 8.3
#
#
# nan
#
#
# The saponification index is measured by weighing 2±0.5 g of sample in an Erlenmeyer flask and adding 25 mL of ethanolic solution of potassium hydroxide with boiling aid. The solution is allowed to boil for 60 minutes and 0.5 mL of phenolphthalein solution is added to the hot solution. The solution is then titrated with 0.1 N HCl and reagent blank is
#
#
# combination of similarity search using BLASTX (RRID:SCR_1,653) and BLASTP (v.2.6.0-1 Camacho et al. 2,009) against UniProt (RRID:SCR_2,380) database (v.2,022-10-12) and hmmscan (v.3.1b2 Finn et al., 2,011) against the Pfam (RRID:SCR_4,726) database was used to assign
#
#
# The PCR products were run by horizontal electrophoresis (Mini-Gel, CBS Scientific, USA) on 1% agarose (Cat # V3,125 Promega, USA) gel with 0.5% ethidium bromide solution (Cat # H5,041 Promega, USA) in 1x TAE buffer (Cat # V4,251 Promega, USA) using a 1kb DNA ladder (Cat # G5,711 Promega, USA) as marker and visual
#
#
# cent review by O’Reilly et al. (2,022) highlighted the effectiveness of stories in fostering critical thinking, such as reasoning and problem-solving among preschoolers, and advocated the utility of story-based approaches in the field of critical thinking for future researchers. Cognitive assessments should be culturally and linguistically relevant to the age
#
#
# Figure 1. (a) Mean and standard deviation of the reasoning scores and (b) the percentage of categories of reasoning responses for the explanation task across the age groups. Figure 2. (a) Mean and standard deviation of the reasoning scores and (b) the percentage of categories of reasoning responses for the prediction task across the age groups. Figure 3. (a) Mean and standard deviation of the reasoning scores under inference, (b) justification of inference, and (c)
#
#
# The MCF-7 and T47D cell lysates were prepared by incubating confluent cells on 6-well culture test plates for 24 hours at 37°C and 5% CO2. The cells were then washed with DPBS, treated with EEOS and rinsed with DPBS before being lysed with 1,000 μl of RIPA lysis buffer. The adhering cells were then removed with the aid of a cell scraper and transferred to micro-tubes before being centrifuged at 6,500 rpm for 10 min at 4°
#
#
# For caspase 3 the amino acid residues contributing to binding ro
#
#
# minoglycosides inhibit protein synthesis by binding the bacterial 30S ribosomal subunit, interfering with bacterial protein translation and leading to cell death.
# swer 3: Rifampicin inhibits the synthesis of Ribonucleic acid (RNA)
#
#
# Detection of drug resistance in NTM can be carried out by drug susceptibility testing (DST) through broth microdilution, sequencing for mutations in the rrl, rrs and rpoB genes, or by using GenoType NTM-DR test (Hain, Lifescience, Neh
#
#
# Horse-Power™ Taq DNA Polymerase MasterMix (Canvax, Córdoba, Spain)
#
#
# The normal range of TGF superfamily (β1 β2 β3) in the blood is 2-12 ng/ml.
# swer 3: The function of IL-1 in cartilage development includes activating matrix-degrading enzymes, suppressing matrix synthesis, and inhibiting chondro
#
#
# nan
#
#
# We treated the somatic cells with low-pH medium according to the protocol described in Obokata et al., 2,014c. We used 5x105 cells/ml of CD45+ splenocytes or lung fibroblasts and treated
#
#
# The set of residues that have at least one atom within SOAS=10 Å from the Cα of D102 in trypsin (PDBid:1A0J) is [D102 W237 M90 V227 M180 G38 R62 S37 D194
#
#
# nan
#
#
# The median values for duration of behavioral states in minutes by treatment during baseline time period were: Standing with head lifted (14.2 minutes), Standing and head rubbing (1.8 minutes), Standing and licking (3.9 minutes), Lying with head lifted (149.7 minutes), Sleeping (22.8 minutes), Lying with
#
#
# nan
#
#
# In the SINGLE conditions for SIZE, the target remains alone; for SPACING, four random flankers (drawn randomly from the alphabet) are added left and right, up and down. In the REPEATED-TARGETS conditions for SIZE, the screen is divided in two, left and right, with each half having its own target. For SPACING, the two targets alternate left and right and up and down to
#
#
# The criteria used to diagnose TB in the study included contact with TB patients, fever, cough, enlarged lymph nodes of the neck, groin, and armpits, nutritional status, bone and joint swelling, chest X-ray (CXR), and Mantoux tuberculin skin test (TST).
# swer 3: The serological test was conducted using the immunodot blot method according to a previous experiment.
# swer 4: The nitrocellulose membrane was pre-wetted using sterile H2
#
#
# The procedure of saliva collection was conducted according to Chiappin et al. Subjects were asked to transfer the collected saliva (a minimum amount of 5 ml) from the mouth to a falcon tube. Saliva samples were immediately deposited into a thermos of ice at 4°C for up to 2 h to protect the unstable analyte and prevent the growth of bacteria prior
#
#
# Yes, there was a statistically significant difference in the sIgA response to Ag38-rec between the confirmed TB
#
#
# dditional fish species downloaded from NCBI include Brown trout (Salmo trutta, JQ390,057 and AF148,843), Broad whitefish (Coregonus nasus
#
#
# Viable (Live Births) fecundability is calculated by multiplying the probability of successful co-localisation of ovum and sperm, successful fertilisation, positive hCG test, and clinical
#
#
# The probability that a fertilised egg will perish prior to implantation is 1 −
#
#
# N(#) is the number of women starting cycle #, N FERT (#) and N SUBF (#) are the modelled number of fertile and sub-fertile women starting cycle #, PREG HCG/FERT (#) and PREG CLIN/FERT (#) are predicted numbers of hCG and clinical pregnancies in fertile women in cycle #, FIN (#) is the number of women who finished the study without becoming clinically pregnant in cycle #, DROP (#) is the number of women who withdrew from the study at the end of cycle #, %fert (#) is the percentage of women starting cycle
#
#
# Measures taken in the pilot study to assess the effects of home-based whole-body exercise training on muscle function included seated leg extension, seated leg flexion, handgrip strength, single-leg 1-RM leg extension, SPPBT (short physical performance battery tests), leg muscle power, heart rate, systolic and diastolic blood pressure, body weight, quadriceps cross-sectional area, vastus lateralis muscle thickness, fascicle length and
#
#
# The most significant results of the comparison of unstable surface versus the
#
#
# The similarities between ShDHODH and SmDHODH sequences do not correlate with the physiochemical parameters; ShDHODH theoretical pI, extinction coefficients, instability index, aliphatic index and grand average of
#
#
# The estimated free energy of binding (kcal/mol) of 3-{[(3-fluoro-3'-methoxybiphenyl-4-yl)amino]carbonyl}thiophene-2-carboxylic acid and 3-{[(3-fluoro-3'-methoxybiphenyl-4-yl)amino]carbonyl}thiophene
#
#
# The accession numbers of the retrieved compounds are 2-({[2,356-TETRAFLUORO-3'-(TRIFLUOROMETHOXY)BIPHENYL-4-YL]AMINO}CARBONYL)CYCLOPENTA-13-DIENE-1-CARBOXYLIC ACID (DB7,978), 3-{[(3-FLUORO-3'-METHOXYBIPHENYL-4-YL)AMINO]CARBONYL}THIOPHENE-2-
#
#
# The researchers simulated dental wear by subjecting the specimens to thermo-mechanical wear (37,000 ER machine, ERIOS, São Paulo, SP, Brazil). Mechanical cycling was performed with a load of 60 N and 100,000 cycles, while thermal cycling was performed with distilled water at temperatures of 5ºC, 37ºC and 55ºC for 30
#
#
# Sodium fluoride treatments and artificial saliva exposure result in an increased surface microhardness of demineralized specimens by increasing the acid resistance of remineralized enamel, which in turn impairs the conditioning effect of the moderate self-etch
#
#
# The H2O2 free radical scavenging capacity of the extracts is determined by the standard method of Debnath et al. (2,009) with slight modifications. This involves mixing 50 µL of the leaf extract with a 30 mM H2O2 solution, vortexing the mixture, and incubating it at room temperature for 60 min. The inhibition percentage is then determined
#
#
# The antioxidant activity in the β
#
#
# healthy male Wister rat (160 g) was deeply anaesthetized with sodium pentobarbital (50 mg/kg body weight) followed by thoracotomy. Terminal cardiac puncture was made in ventricle using an appropriate sterile needle and blood drawn slowly and collected in PBS-EDTA solution, diluted by 1X PBS in 1:1 ratio and laid on Histopaque-1,077 (HiMedia, India), a density gradient cell separation medium of ficoll and sodium diatrizo
#
#
# To determine testicular GST activity, 0.5 mM glutathione, 0.1 M sodium phosphate buffer, pH 7.3 and 0.5 mM 1-chloro-24-dinitrobenzene (CDNB) must be added to the tissue sample. The CDNB
#
#
# The in vitro study revealed that tangeretin is a potent and regioselective stimulator of midazolam 1'-hydroxylation and complementary DNA-expressed CYP3A4. However, further studies are needed to confirm the clinical effect
#
#
# nan
#
#
# HUMAnN2 partially answers this question by including taxa in its gene family and pathway outputs, but it does not include the taxa's abundance, only the functional abundance. We can fill
#
#
# The FacetZoom reveals the common taxonomic features while the Stacked Plots show the proportion of all features aggregated to the Order level. The scatter plots display the samples with WGS abundance on the X-axis and 16S abundance on
#
#
# The three types of umbilical-porta-systemic venous shunt (UPSVS) are Type I, umbilical–systemic shunt (USS), with the blood flow from the umbilical vein entered directly into the systemic veins; Type II, ductus venosus–systemic shunt (DVSS), with the DV blood flow shunted from its normal path into the systemic veins; and Type III, portal–systemic shunt, which divided into two subgroups: Type IIIa, intrahepatic portal–systemic shunt (IHPSS), with an intrahepatic shunt between the IHPVS and the hepatic vein; and Type IIIb, extrahepatic portal–systemic shunt (EHPSS), with an
#
#
# The researchers incubated the samples with the magnetic bead mixture for 10 minutes, magnet
#
#
# comprehensive literature search that aims to identify the available evidence as completely as possible is the foundation of every systematic review.
# swer: According to current recommendations, systematic search approaches should include both electronic database searching and one or several supplementary search methods, such as citation tracking, contacting study authors or experts, handsearching, trial register searching, and web searching.
# swer: Citation tracking is an umbrella term for multiple methods which directly or indirectly collect related references from so called "seed references". These seed references are usually eligible for inclusion into the review
#
#
# The criteria for including a study in the scope of this review are any study with a focus on citation tracking as an evidence retrieval method and one of the following: any study assessing the benefit and/or effectiveness of citation tracking; any study comparing different methods of citation tracking (e.g., backward vs. forward, direct vs. indirect); any study assessing technical uses of citation tracking (e.g., comparing citation indexes and/or tools, e.g., Scopus vs
#
#
# The two cycles of lessons used for the action research were cycle 1 with “static” submicro representations (PowerPoint slides) to teach stoichiometry and cycle 2 with “dynamic” submicro representations, which included “dynamic” submicro diagrams (molecular graphics manipulated with the computer - hands-on approach) and submicro models (physical molecular models manipulated by hand - hands-on approach
#
#
# nan
#
#
# The stem cells were further cultured by adding 2cc complete medium DMEM one time, 10% fetal bovine serum (FBS), 50ug/ml
#
#
# RNF-111 has a slightly higher activity than TGF-β1 in activating TGF-β1 receptors, indicating that it plays a synergistic role in the process of chondrogenesis through the TGF-β1R pathway.
# swer 3: Chen et al. observed that treatment with CM-MSCs had a satisfying effect on reducing the progression of OA in mice, by protecting microarchitecture from subchondral bones, balancing the MMP-13 and TIMP-1 ratios
#
#
# ...
# swer 4: Selection bias was originally going to
#
# Corresponding Question 10208: What languages were included in the meta-analyses?
# Truncated Answer  10208: The meta-analyses included studies in English and Norwegian, as these are the two languages spoken fluently by the primary investigator, MO.
# swer 3: Data extraction for the qualitative summary was checked by a second reviewer, but only a sample of data was extracted due to limited time and resources. There were no errors in the sample.
# swer 4: Selection bias was originally going to
# Number of rows in filtered data: 23
# Number of rows in remaining data: 9771
#
# Original text:  The studies were done by Hall
#                 et al.,
#
# 11
#  and Arezzo
#                 et al.,
#
# 9
#  stated the VAS did not differ significantly. Meanwhile, Lirici
#                 et al.,
#
# 62
#  demonstrated an improvement in VAS after day one, although the pain score on day one did not show any differences between SILC and CMLC. On the other hand, Evers
#                 et al.,
#
# 7
#  revealed a superior VAS outcome in the SILC group at 24 hours. The opposite outcomes were reported by Lyu
#                 et al.,,
#
# 12
#  in which SILC remained inferior for post-operative pain reduction at 6, 8, 12 and 24 hours. The heterogeneity of VAS was influenced by many elements, including the type of anaesthetic drugs, length of incision, and psychological factors. Thus, our study reported a high degree of heterogeneity. In terms of cosmesis, the superiority of SILC was undoubtedly observed. Our study reported better cosmetic results at both the one-month and six-month post-operative outcomes. Multiple studies have also supported our results. 7
#
# ,
#
# 9
#
# ,
#
# 11
#
# ,
#
# 62
#  The advantage of having a single incision at the umbilical creates a seamless scar, increasing the patient’s satisfaction.
# Corrected text:  The studies were done by Hall
#                 et al.,
#
# 11
#  and Arezzo
#                 et al.,
#
# 9
#  stated the VAS did not differ significantly. Meanwhile, Lirici
#                 et al.,
#
# 62
#  demonstrated an improvement in VAS after day one, although the pain score on day one did not show any differences between SILC and CMLC. On the other hand, Evers
#                 et al.,
#
# 7
#  revealed a superior VAS outcome in the SILC group at 24 hours. The opposite outcomes were reported by Lyu
#                 et al.,
#
# 12
#  in which SILC remained inferior for post-operative pain reduction at 6, 8, 12 and 24 hours. The heterogeneity of VAS was influenced by many elements, including the type of anaesthetic drugs, length of incision, and psychological factors. Thus, our study reported a high degree of heterogeneity. In terms of cosmesis, the superiority of SILC was undoubtedly observed. Our study reported better cosmetic results at both the one-month and six-month post-operative outcomes. Multiple studies have also supported our results. 7
#
# ,
#
# 9
#
# ,
#
# 11
#
# ,
#
# 62
#  The advantage of having a single incision at the umbilical creates a seamless scar, increasing the patient’s satisfaction.
#
# Original text:  The studies were done by Hall
#                 et al.,
#
# 11
#  and Arezzo
#                 et al.,
#
# 9
#  stated the VAS did not differ significantly. Meanwhile, Lirici
#                 et al.,
#
# 62
#  demonstrated an improvement in VAS after day one, although the pain score on day one did not show any differences between SILC and CMLC. On the other hand, Evers
#                 et al.,
#
# 7
#  revealed a superior VAS outcome in the SILC group at 24 hours. The opposite outcomes were reported by Lyu
#                 et al.,,
#
# 12
#  in which SILC remained inferior for post-operative pain reduction at 6, 8, 12 and 24 hours. The heterogeneity of VAS was influenced by many elements, including the type of anaesthetic drugs, length of incision, and psychological factors. Thus, our study reported a high degree of heterogeneity. In terms of cosmesis, the superiority of SILC was undoubtedly observed. Our study reported better cosmetic results at both the one-month and six-month post-operative outcomes. Multiple studies have also supported our results. 7
#
# ,
#
# 9
#
# ,
#
# 11
#
# ,
#
# 62
#  The advantage of having a single incision at the umbilical creates a seamless scar, increasing the patient’s satisfaction.
# Corrected text:  The studies were done by Hall
#                 et al.,
#
# 11
#  and Arezzo
#                 et al.,
#
# 9
#  stated the VAS did not differ significantly. Meanwhile, Lirici
#                 et al.,
#
# 62
#  demonstrated an improvement in VAS after day one, although the pain score on day one did not show any differences between SILC and CMLC. On the other hand, Evers
#                 et al.,
#
# 7
#  revealed a superior VAS outcome in the SILC group at 24 hours. The opposite outcomes were reported by Lyu
#                 et al.,
#
# 12
#  in which SILC remained inferior for post-operative pain reduction at 6, 8, 12 and 24 hours. The heterogeneity of VAS was influenced by many elements, including the type of anaesthetic drugs, length of incision, and psychological factors. Thus, our study reported a high degree of heterogeneity. In terms of cosmesis, the superiority of SILC was undoubtedly observed. Our study reported better cosmetic results at both the one-month and six-month post-operative outcomes. Multiple studies have also supported our results. 7
#
# ,
#
# 9
#
# ,
#
# 11
#
# ,
#
# 62
#  The advantage of having a single incision at the umbilical creates a seamless scar, increasing the patient’s satisfaction.
#
# Original text:  Median age
#                                      39.5; 48 male (
#                                     n=50)
# Suicide
#                                      attempts/self-
#                                     harm
# Three of the 50 referrals had self
#                                      harmed. The self-harm was apparently
#                                      a reaction to the pandemic. Two were
#                                      asymptomatic for COVID-19, and one
#                                      had a mild case. Focus is on psychiatric presentations in
#                                      people with acute infections, the long
#                                     term impact of COVID-19 infection on
#                                      psychiatric morbidity requires further
#                                      study. Peer reviewed. Jefsen
#                                         et al., 2020a
#
# Rohde
#                                         et al., 2020
#
# Denmark
# Review of notes of adult patients from
#                                      the psychiatric services of  the Central
#                                     Denmark Region (catchment area: 1.3
#                                      million people). Notes between 1 Feb and 23 March
#                                      2020 reviewed to identify those
#                                      describing "pandemic-related psychiatric
#                                      symptoms" (including "self harm /
#                                     suicidality",
#                                     n=74). Median age 29.8
#                                      years; 77% female
#
# Note full case series  n=1357 relevant
#                                      records found from 412,804, reported in
#
# Rohde
#                                         et al.,, 2020. Suicide
#                                      attempts/self-
#                                     harm, suicidal
#                                     thoughts
# Of the 74 patients identified, 14 (19%)
#                                      had self-harm thoughts; 10 (14%) had
#                                      self-harmed; 34 (46%) had suicidal
#                                     thoughts; 10 (14%) had made suicide
#                                      attempts and 13 (18%) had a passive
#                                      wish to die from COVID-19.
# Corrected text:  Median age
#                                      39.5; 48 male (
#                                     n=50)
# Suicide
#                                      attempts/self-
#                                     harm
# Three of the 50 referrals had self
#                                      harmed. The self-harm was apparently
#                                      a reaction to the pandemic. Two were
#                                      asymptomatic for COVID-19, and one
#                                      had a mild case. Focus is on psychiatric presentations in
#                                      people with acute infections, the long
#                                     term impact of COVID-19 infection on
#                                      psychiatric morbidity requires further
#                                      study. Peer reviewed. Jefsen
#                                         et al., 2020a
#
# Rohde
#                                         et al., 2020
#
# Denmark
# Review of notes of adult patients from
#                                      the psychiatric services of  the Central
#                                     Denmark Region (catchment area: 1.3
#                                      million people). Notes between 1 Feb and 23 March
#                                      2020 reviewed to identify those
#                                      describing "pandemic-related psychiatric
#                                      symptoms" (including "self harm /
#                                     suicidality",
#                                     n=74). Median age 29.8
#                                      years; 77% female
#
# Note full case series  n=1357 relevant
#                                      records found from 412,804, reported in
#
# Rohde
#                                         et al.,  2020. Suicide
#                                      attempts/self-
#                                     harm, suicidal
#                                     thoughts
# Of the 74 patients identified, 14 (19%)
#                                      had self-harm thoughts; 10 (14%) had
#                                      self-harmed; 34 (46%) had suicidal
#                                     thoughts; 10 (14%) had made suicide
#                                      attempts and 13 (18%) had a passive
#                                      wish to die from COVID-19.
#
# Original text:  Median age
#                                      39.5; 48 male (
#                                     n=50)
# Suicide
#                                      attempts/self-
#                                     harm
# Three of the 50 referrals had self
#                                      harmed. The self-harm was apparently
#                                      a reaction to the pandemic. Two were
#                                      asymptomatic for COVID-19, and one
#                                      had a mild case. Focus is on psychiatric presentations in
#                                      people with acute infections, the long
#                                     term impact of COVID-19 infection on
#                                      psychiatric morbidity requires further
#                                      study. Peer reviewed. Jefsen
#                                         et al., 2020a
#
# Rohde
#                                         et al., 2020
#
# Denmark
# Review of notes of adult patients from
#                                      the psychiatric services of  the Central
#                                     Denmark Region (catchment area: 1.3
#                                      million people). Notes between 1 Feb and 23 March
#                                      2020 reviewed to identify those
#                                      describing "pandemic-related psychiatric
#                                      symptoms" (including "self harm /
#                                     suicidality",
#                                     n=74). Median age 29.8
#                                      years; 77% female
#
# Note full case series  n=1357 relevant
#                                      records found from 412,804, reported in
#
# Rohde
#                                         et al.,, 2020. Suicide
#                                      attempts/self-
#                                     harm, suicidal
#                                     thoughts
# Of the 74 patients identified, 14 (19%)
#                                      had self-harm thoughts; 10 (14%) had
#                                      self-harmed; 34 (46%) had suicidal
#                                     thoughts; 10 (14%) had made suicide
#                                      attempts and 13 (18%) had a passive
#                                      wish to die from COVID-19.
# Corrected text:  Median age
#                                      39.5; 48 male (
#                                     n=50)
# Suicide
#                                      attempts/self-
#                                     harm
# Three of the 50 referrals had self
#                                      harmed. The self-harm was apparently
#                                      a reaction to the pandemic. Two were
#                                      asymptomatic for COVID-19, and one
#                                      had a mild case. Focus is on psychiatric presentations in
#                                      people with acute infections, the long
#                                     term impact of COVID-19 infection on
#                                      psychiatric morbidity requires further
#                                      study. Peer reviewed. Jefsen
#                                         et al., 2020a
#
# Rohde
#                                         et al., 2020
#
# Denmark
# Review of notes of adult patients from
#                                      the psychiatric services of  the Central
#                                     Denmark Region (catchment area: 1.3
#                                      million people). Notes between 1 Feb and 23 March
#                                      2020 reviewed to identify those
#                                      describing "pandemic-related psychiatric
#                                      symptoms" (including "self harm /
#                                     suicidality",
#                                     n=74). Median age 29.8
#                                      years; 77% female
#
# Note full case series  n=1357 relevant
#                                      records found from 412,804, reported in
#
# Rohde
#                                         et al.,  2020. Suicide
#                                      attempts/self-
#                                     harm, suicidal
#                                     thoughts
# Of the 74 patients identified, 14 (19%)
#                                      had self-harm thoughts; 10 (14%) had
#                                      self-harmed; 34 (46%) had suicidal
#                                     thoughts; 10 (14%) had made suicide
#                                      attempts and 13 (18%) had a passive
#                                      wish to die from COVID-19.
# Total comma count: 0
# File: C:/Users/Joshua Giwa/Downloads/QnAs_generated_26_07_2023/QnA_Biomass_f1000_20230717.csv
#
# Total undesirable questions: 24
# Total Truncated Questions: 46
# Total Truncated Answers: 417
# excessive comma occurence: 0
# (undesirable_questions + Truncated Questions + Truncated Answers + excessive comma occurence): 487
#
# Script ran for 302.02 minutes.

# %% [markdown]
# ### !jupyter notebook list

# %%
from jupyter_core.paths import jupyter_config_dir
jupyter_dir = jupyter_config_dir()
jupyter_dir
# Out:
# 'C:\\Users\\Joshua Giwa\\.jupyter'
